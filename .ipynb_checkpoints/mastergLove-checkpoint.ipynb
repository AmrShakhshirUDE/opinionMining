# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten,Embedding,Activation,Dropout
from tensorflow.keras.layers import Conv1D, MaxPooling1D,GlobalMaxPooling1D,LSTM
from tensorflow.keras.optimizers import Adam

import re
import numpy as np
from numpy import array
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split

# %%
abbreviations ={
    "’": "'",
    "ain't": "am not",
    "aren't": "are not",
    "can't": "cannot",
    "can't've": "cannot have",
    "'cause'": "because",
    "could've": "could have",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hadn't've": "had not have",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he would",
    "he'd've": "he would have",
    "he'll": "he will",
    "he'll've": "he will have",
    "he's": "he is",
    "how'd": "how did",
    "how'd'y": "how do you",
    "how'll": "how will",
    "how's": "how does",
    "i'd": "i would",
    "i'd've": "i would have",
    "i'll": "i will",
    "i'll've": "i will have",
    "i'am": "i am",
    "i've": "i have",
    "isn't": "is not",
    "it'd": "it would",
    "it'd've": "it would have",
    "it'll": "it will",
    "it'll've": "it will have",
    "it's": "it is",
    "let's": "let us",
    "ma'am": "madam",
    "mayn't": "may not",
    "might've": "might have",
    "mightn't": "might not",
    "mightn't've": "might not have",
    "must've": "must have",
    "mustn't": "must not",
    "mustn't've": "must not have",
    "needn't": "need not",
    "needn't've": "need not have",
    "o'clock": "of the clock",
    "oughtn't": "ought not",
    "oughtn't've": "ought not have",
    "shalln't": "shall not",
    "shan't": "shall not",
    "shan't've": "shall not have",
    "sha'n't": "shall not",
    "she'd": "she would",
    "she'd've": "she would have",
    "she'll": "she will",
    "she'll've": "she will have",
    "she's": "he is",
    "shouldn've": "should have",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "so've": "so have",
    "so's": "so is",
    "that'd": "that would",
    "that'd've": "that would have",
    "that's": "that is",
    "there'd": "there would",
    "there'd've": "there would have",
    "there'is": "there is",
    "they'd": "they would",
    "they'd've": "they would have",
    "they'll": "they will",
    "they'll've": "they will have",
    "they're": "they are",
    "they've": "they have",
    "to've": "to have",
    "wasn't": "was not",
    "were't": "were not",
    " u ": "you",
    " ur ": "your",
    "you’re": "you are",
    "you're": "you are",
    " u'r ": "you are",
    " n ": "and",
    " lil mor ": "little more",
    " can' ": "cannot",
    " gov re ": "government regulations",
    " yea ": " yes ",
    " yeah ": " yes ",    
}

# %%
indomain= pd.read_csv('./datasets/indomain.csv', encoding='utf8') #onlyTweets
indomain.head()
# Out:
#                                                tweet subjectivity
# 0  @VancityReynolds @vincenzolandino @007 does Ca...   subjective
# 1  @VancityReynolds @vincenzolandino @007 ????yea...   subjective
# 2  @VancityReynolds @vincenzolandino @007 We all ...   subjective
# 3  @VancityReynolds @vincenzolandino @007 You wou...   subjective
# 4  HE LOOKS LIKE AN AGENT OR KINGSMAN TYPE OF SHI...   subjective

# %%
outdomain= pd.read_csv('./datasets/outdomain.csv',sep=',', encoding='utf-8') #onlyTweets
outdomain.head()
# Out:
#                                                tweet subjectivity ts  \
# 0  Oh right but if you're one of those absolute w...   subjective  y
# 1  I ate the squid game burger.  https://t.co/wqV...    objective  y
# 2  It was 5011 million Squid Games costumes and p...   subjective  y
# 3  If you enjoyed squid game, you should definite...   subjective  y
# 4  Social inequality and hyper violence: why the ...    objective  y
#
#        actual
# 0  subjective
# 1   objective
# 2  subjective
# 3  subjective
# 4   objective

# %% [markdown]
# ### Translating emojis

# %%
with open('./dictionaries/Emoji_Dict.p', 'rb') as fp:
    Emoji_Dict = pickle.load(fp)
Emoji_Dict = {v: k for k, v in Emoji_Dict.items()}

def convert_emojis_to_word(text):
    for emot in Emoji_Dict:
        text = re.sub(r'('+emot+')', "_".join(Emoji_Dict[emot].replace(",","").replace(":","").split()) +' emojihasbeendetected ', text)
    return text

# %%
indomain["tweet"]=indomain["tweet"].apply(convert_emojis_to_word)
indomain["tweet"]
# time 1m11.8s
# Out:
# 0      @VancityReynolds @vincenzolandino @007 does Ca...
# 1      @VancityReynolds @vincenzolandino @007 ????yea...
# 2      @VancityReynolds @vincenzolandino @007 We all ...
# 3      @VancityReynolds @vincenzolandino @007 You wou...
# 4      HE LOOKS LIKE AN AGENT OR KINGSMAN TYPE OF SHI...
#                              ...
# 839    Police officers who guard Downing Street have ...
# 840    A jury has criticised police and prosecutors a...
# 841    Former model Katie Price faces a possible pris...
# 842    Nearly two thirds of the public back the aboli...
# 843    Deputy Prime Minister Dominic Raab said on Sun...
# Name: tweet, Length: 844, dtype: object

# %%
outdomain["tweet"]=outdomain["tweet"].apply(convert_emojis_to_word)
outdomain["tweet"]
# time 56.8s
# Out:
# 0      Oh right but if you're one of those absolute w...
# 1      I ate the squid game burger.  https://t.co/wqV...
# 2      It was 5011 million Squid Games costumes and p...
# 3      If you enjoyed squid game, you should definite...
# 4      Social inequality and hyper violence: why the ...
#                              ...
# 665     @CristianoXtra_ Uneducated Admin, This is 202...
# 666    Lionel Messi said Lewandowski deserves the Bal...
# 667    FIFA Club World Cup in 2020 and he's won the C...
# 668    Li Tie was appointed as the China national hea...
# 669    My top 5 last games i played are  1  FIFA 2021...
# Name: tweet, Length: 670, dtype: object

# %% [markdown]
# ### Preprocessing function

# %%
import string
import re
def cleanTweets(tweet):
    tweet= re.sub(r'@[A-Za-z0-9]+','',tweet)                            #remove @mentions;r-> the expression is a raw string,+ -> one char or more
    tweet= re.sub(r'#','',tweet)                                        #remove '#' Symbol
    # tweet= re.sub(r'RT[\s]+','',tweet)                                  #remove RT
    tweet= re.sub(r'https?:\/\/\S+','websiteisgiven',tweet)             #replace hyper links
    # tweet= tweet.lower()                                                #convert to lowercase
    # tweet= re.sub(r'\d+', '', tweet)                                    #remove numbers (DON'T activate it if numbers in text are relevant)
    translator = str.maketrans('', '', string.punctuation)
    tweet= tweet.translate(translator)                                  #remove punctuations
    # tweet = re.sub(r"[!\"#$%&'()*+,\-/:;<=>@[\]^_`{|}~]", '', tweet)
    return tweet

# %%
# %%time
indomain['tweet']= indomain['tweet'].apply(lambda txt:cleanTweets(txt))
print(indomain['tweet'])
# Out:
# 0         does Canada have its own spy agency lol the...
# 1                       yea I dont want ya as James Bond
# 2         We all love Ryan but hes Canadian and inste...
# 3         You woud make a great James Bond but you wo...
# 4      HE LOOKS LIKE AN AGENT OR KINGSMAN TYPE OF SHI...
#                              ...
# 839    Police officers who guard Downing Street have ...
# 840    A jury has criticised police and prosecutors a...
# 841    Former model Katie Price faces a possible pris...
# 842    Nearly two thirds of the public back the aboli...
# 843    Deputy Prime Minister Dominic Raab said on Sun...
# Name: tweet, Length: 844, dtype: object
# CPU times: total: 15.6 ms
# Wall time: 5 ms

# %%
# %%time
outdomain['tweet']= outdomain['tweet'].apply(lambda txt:cleanTweets(txt))
print(outdomain['tweet'])
# Out:
# 0      Oh right but if youre one of those absolute we...
# 1            I ate the squid game burger  websiteisgiven
# 2      It was 5011 million Squid Games costumes and p...
# 3      If you enjoyed squid game you should definitel...
# 4      Social inequality and hyper violence why the b...
#                              ...
# 665      Uneducated Admin This is 2020 FIFA The Best ...
# 666    Lionel Messi said Lewandowski deserves the Bal...
# 667    FIFA Club World Cup in 2020 and hes won the CA...
# 668    Li Tie was appointed as the China national hea...
# 669    My top 5 last games i played are  1  FIFA 2021...
# Name: tweet, Length: 670, dtype: object
# CPU times: total: 0 ns
# Wall time: 6 ms

# %%
import re
inText=' '.join(indomain['tweet'])
inText=inText.split()
inFreqComm= pd.Series(inText).value_counts()
inRare=inFreqComm[inFreqComm.values==1] # get words that have been occured a single time to be removed from dataset

def getCleanTextIn(txt):
    if type(txt) is str:
        txt=txt.lower()
        for key in abbreviations:                                                   #transform abbreviations into complete words
            value = abbreviations[key]
            txt=txt.replace(key, value)
#         # txt=re.sub(r'[A-Za-z0-9+._-]+@[A-Za-z0-9+._-]+\.[A-Za-z0-9+._-]+','',txt)   #remove emails
#         txt= re.sub(r'@[A-Za-z0-9]+','',txt)                                        #remove @mentions;r-> the expression is a raw string,+ -> one char or more
#         txt= re.sub(r'#','',txt)                                                    #remove '#' Symbol
#         txt= re.sub(r'RT[\s]+','',txt)                                              #remove RT
#         txt= re.sub(r'https?:\/\/\S+','websiteisgiven',txt)                         #transform all hyper links to keys
#         # txt=re.sub('[^A-Z a-z]+','',txt)                                            #keep only charecters
        # txt=' '.join([term for term in txt.split() if term not in rare])            #keep only frequent words/ neglect once occured words
        return txt
    else:
        return txt

# %% [markdown]
# ## Translator

# %%
# from deep_translator import GoogleTranslator

# translated1=[]
# for i in indomain['tweet']:
#     translated1.append(GoogleTranslator(source='auto', target='de').translate(i))
# translated1

# # time 19m37.1s

# # to_translate = 'I want to translate this text'
# # translated = GoogleTranslator(source='auto', target='de').translate(to_translate)
# # outpout -> Ich möchte diesen Text übersetzen

# %%
# %%time
# translated=[]
# for i in translated1:
#     translated.append(GoogleTranslator(source='auto', target='en').translate(i))
# translated

# # time: 11min 15.4s

# %%
# tweets=indomain["tweet"].tolist()
# type(tweets)
# tweets=tweets+translated
# tweets

# %% [markdown]
# ### Write translated to text file

# %%
# textfile = open("./translated/listFlie.txt", "w",encoding="utf-8")
# for element in tweets:
#     textfile.write(element + "\n")
# textfile.close()

# %% [markdown]
# ### End of translation configuration

# %% [markdown]
# ### Read translated from text file

# %%
#Make sure to remove last empty line from listFile.txt before run this snippet
my_file = open("./translated/listFlie.txt", "r",encoding="utf-8",newline="\r\n")
listText = my_file.read().split("\r\n")
# listText

# %%
translatedList= pd.Series(listText)
translatedList
start=len(indomain['tweet'])
translatedList=translatedList[start:len(translatedList)]
translatedList
# Out:
# 844     Does Canada have its own spy agency lol they s...
# 845                   Yes, I don't want you as James Bond
# 846     We all love Ryan but he is Canadian and instea...
# 847     You'd make a great James Bond, but you'd have ...
# 848     HE LOOKS LIKE AN AGENT OR KINGSMAN TYPE OF SHI...
#                               ...
# 1683    Police officers guarding Downing Street were i...
# 1684    A jury has criticized police and prosecutors a...
# 1685    Former model Katie Price faces possible jail t...
# 1686    Almost two-thirds of the public supports scrap...
# 1687    Deputy Prime Minister Dominic Raab said on Sun...
# Length: 844, dtype: object

# %%
# type(translatedList)

# %% [markdown]
# ## End of translation

# %% [markdown]
# ### Text cleaning

# %%
ouText=' '.join(outdomain['tweet'])
ouText=ouText.split()
outFreqComm= pd.Series(ouText).value_counts()
outRare=outFreqComm[outFreqComm.values==1] # get words that have been occured a single time to be removed from dataset

def getCleanTextOut(txt):
    if type(txt) is str:
        txt=txt.lower()
        for key in abbreviations:                                                   #transform abbreviations into complete words
            value = abbreviations[key]
            txt=txt.replace(key, value)
#         # txt=re.sub(r'[A-Za-z0-9+._-]+@[A-Za-z0-9+._-]+\.[A-Za-z0-9+._-]+','',txt)   #remove emails
#         txt= re.sub(r'@[A-Za-z0-9]+','',txt)                                        #remove @mentions;r-> the expression is a raw string,+ -> one char or more
#         txt= re.sub(r'#','',txt)                                                    #remove '#' Symbol
#         txt= re.sub(r'RT[\s]+','',txt)                                              #remove RT
#         txt= re.sub(r'https?:\/\/\S+','websiteisgiven',txt)                         #transform all hyper links to keys
#         txt=re.sub('[^A-Z a-z]+','',txt)                                            #keep only charecters
#         txt=' '.join([term for term in txt.split() if term not in rare])            #keep only frequent words/ neglect once occured words
        return txt
    else:
        return txt

# %%
# %%time
# tweets= tweets.apply(lambda txt:getCleanTextIn(txt))
# print(tweets)

# %%
# %%time
indomain['tweet']= indomain['tweet'].apply(lambda txt:getCleanTextIn(txt))
print(indomain['tweet'])
# Out:
# 0         does canada have its own spy agency lol the...
# 1                       yes i dont want ya as james bond
# 2         we all love ryan but hes canadian and inste...
# 3         you woud make a great james bond but you wo...
# 4      he looks like an agent or kingsman type of shi...
#                              ...
# 839    police officers who guard downing street have ...
# 840    a jury has criticised police and prosecutors a...
# 841    former model katie price faces a possible pris...
# 842    nearly two thirds of the public back the aboli...
# 843    deputy prime minister dominic raab said on sun...
# Name: tweet, Length: 844, dtype: object
# CPU times: total: 15.6 ms
# Wall time: 12 ms

# %%
# %%time
outdomain['tweet']= outdomain['tweet'].apply(lambda txt:getCleanTextOut(txt))
print(outdomain['tweet'])
# Out:
# 0      oh right but if youre one of those absolute we...
# 1            i ate the squid game burger  websiteisgiven
# 2      it was 5011 million squid games costumes and p...
# 3      if you enjoyed squid game you should definitel...
# 4      social inequality and hyper violence why the b...
#                              ...
# 665      uneducated admin this is 2020 fifa the best ...
# 666    lionel messi said lewandowski deserves the bal...
# 667    fifa club world cup in 2020 and hes won the ca...
# 668    li tie was appointed as the china national hea...
# 669    my top 5 last games i played are  1  fifa 2021...
# Name: tweet, Length: 670, dtype: object
# CPU times: total: 15.6 ms
# Wall time: 12 ms

# %% [markdown]
# ### Cleaning translated

# %%
translatedList= translatedList.apply(lambda txt:cleanTweets(txt))
translatedList
# Out:
# 844     Does Canada have its own spy agency lol they s...
# 845                     Yes I dont want you as James Bond
# 846     We all love Ryan but he is Canadian and instea...
# 847     Youd make a great James Bond but youd have to ...
# 848     HE LOOKS LIKE AN AGENT OR KINGSMAN TYPE OF SHI...
#                               ...
# 1683    Police officers guarding Downing Street were i...
# 1684    A jury has criticized police and prosecutors a...
# 1685    Former model Katie Price faces possible jail t...
# 1686    Almost twothirds of the public supports scrapp...
# 1687    Deputy Prime Minister Dominic Raab said on Sun...
# Length: 844, dtype: object

# %%
# %%time
translatedList= translatedList.apply(lambda txt:getCleanTextIn(txt))
translatedList
# Out:
# CPU times: total: 15.6 ms
# Wall time: 11 ms
# 844     does canada have its own spy agency lol they s...
# 845                     yes i dont want you as james bond
# 846     we all love ryan but he is canadian and instea...
# 847     youd make a great james bond but youd have to ...
# 848     he looks like an agent or kingsman type of shi...
#                               ...
# 1683    police officers guarding downing street were i...
# 1684    a jury has criticized police and prosecutors a...
# 1685    former model katie price faces possible jail t...
# 1686    almost twothirds of the public supports scrapp...
# 1687    deputy prime minister dominic raab said on sun...
# Length: 844, dtype: object

# %% [markdown]
# #### Numerizing target values

# %%
indomain['subjectivity'].value_counts()
# Out:
# objective     433
# subjective    411
# Name: subjectivity, dtype: int64

# %%
outdomain['subjectivity'].value_counts()
# Out:
# subjective    466
# objective     204
# Name: subjectivity, dtype: int64

# %%
inText = indomain['tweet'].tolist()   #convert series to list
print('rows are: ',len(inText))
print('columns are: ',len(inText[0]))
inText[:3]                            #show 3 lines
# Out:
# rows are:  844
# columns are:  158
# ['   does canada have its own spy agency lol they send him undercover to stop the japanese mafia from selling imitation canadian bacon in a hot fuzz style movie',
#  '   yes i dont want ya as james bond',
#  '   we all love ryan but hes canadian and instead of killing the baddie he would try to talk them down by being nice']

# %% [markdown]
# ## Concat translated to original

# %%
translatedList=translatedList.tolist()
translatedList
# Out:
# ['does canada have its own spy agency lol they send him undercover to stop the japanese mafia from selling imitation canadian bacon in a hot fuzz style movie',
#  'yes i dont want you as james bond',
#  'we all love ryan but he is canadian and instead of killing the bad guy he would try to calm her down by being nice',
#  'youd make a great james bond but youd have to swap the gin for a martini',
#  'he looks like an agent or kingsman type of shit in 2nd go james bond go james bond go go go go',
#  'i agree with ryan reynolds i like the tradition of having english actors play bond and a really controversial actor is someone like idris alba its time',
#  'disappointed in the new jamesbond movie its like they killed the franchise',
#  'james bond dies at the end of the film last line in the credits',
#  'saw the latest james bond film at this fantastic cinema last weekend art direction and styling rud',
#  'beautiful photo',
#  'has anyone ever set a timer on their amazon alexa for 6 minutes only to end it after 3 minutes',
#  'worst bond film of all time',
#  'yes everyone loves ryan',
#  'and and and',
#  'hey why dont you do your own new james bond series',
#  'well',
#  'are you crazy the only logical direction is the jinx series unless it wants 2 it also has a pretty good director',
#  'no',
#  'who is this man james bond',
#  'congratulations capt william h wiley amp',
#  'he would admittedly make a good q',
#  'discover the connection between the vegetable broccoli and the james bond website',
#  '7910 098 077 mr 007 is',
#  'the ending was a bad decision that i think the producers will regret i mean brosnan had to end up in bed with halle berry',
#  'and and and',
#  'more bean than bond',
#  'watch james bond tn',
#  'i spent 18 to see no time to die',
#  'oops spoiler alert you need to check out the rest of the infinity saga',
#  'when i was in high school 9 years ago thai fans cite adeles comeback when she used skyfall as the soundtrack of james bonds film adele tornado',
#  'oh come on i bet you have an amazing british accent',
#  'i am open to offers sell my 1953 safins mask',
#  'i really enjoyed notimetodie',
#  'i dont see tom in another spidey movie',
#  'listen to bonus episode now weve unlocked our first patreonexclusive agents in the field episode for your listening pleasure download our review of 1996 the rock and find out what youre missing listen now',
#  'from the plot of the new james bond film',
#  'likewise',
#  'prins dang i missed that part',
#  'discussion of notimetodie with continues with episode 5 minor characters were talking about the scooby gang',
#  'why cant they just cast henry cavill as the next best fitting james bond man',
#  'tom holland for the new james bond',
#  'would never allow that he would cut off ryans arms and legs just to avoid him playing bond',
#  'wonderful brings back memories of a tour with james bond',
#  'james bond no time to die is without a doubt the most breathtaking',
#  'i actually ordered the entire jamesbond collection on bluray because i wanted the notimetodie steelbook',
#  'its right hard no its owned by the british but it would be phenomenal to see a person of color in the role that im looking at you in',
#  'and and and',
#  'counterpoint as villain',
#  'you would never replace rowan as johnny english',
#  'a problem james bond doesnt cry about',
#  'no he must be british',
#  'i have a question which franchise was the name or number james bond or 007',
#  'ironman is dead',
#  'im imagining agent 86 more',
#  'i couldnt take ryan reynolds seriously as james bond',
#  'i cant imagine james bond playing dirty dozens before killing a villain wouldnt be british',
#  'the future should be known as the 007 series and the current james bond train have 4 new spies to be the next 007 whatever the fan favorite is the next 007 will make it more inclusive and 007 a cloak too instead of james b',
#  'right',
#  'die matrixtrilogie',
#  'i hereby call on the broccoli dynasty to cast the first male bond babe with the already taken name pussy galore',
#  'james bond and johnny english crossover please',
#  'introducing the first female james bond ffxiv ff14 gposers eorzeaphotos ffxivscreenshots website',
#  'james bond and its not close',
#  'personally think it should go',
#  'my cat actually watches james bond with our website',
#  'james bond is british correct',
#  'tom holland as james bond would actually give me a reason to watch the 007 movies',
#  'how about the brave canadian csis agent who first annoys 007 and then helps later in the film bond is in trouble and out of nowhere ryan flies in and saves 007 later they have aviation gin martinis and bond co',
#  'well he hasnt he literally blew up the damn thing i will completely ignore the craig era and move on to the sequel to dad',
#  '7910 098 077',
#  'nextjamesbond ryan reynolds announces interest in 007 role can he beat tom hardy jamesbond website launched',
#  'thoughts are given on no time to die friday morning jamesbond writingcommunity website',
#  'denmark 7910 098 077',
#  'hes too funny im not sure if it works',
#  'no no no yes we used to think you were just a pretty face with a gorgeous body but you are so much more i would pay more money to listen to your natural sense of selfdeprecating humor',
#  'every halle berry moment and an invisible car too',
#  'actually',
#  'i mean 7910 098 077',
#  'and and and',
#  'do not do that',
#  'if its true that tom holland wants to play james bond if he does it will be a good tomholland james bond',
#  'looks beautiful',
#  'dont you think dr no no no',
#  'thats a clue right there double no seven',
#  'although i love both actor two doesnt fit as james bond',
#  'fine',
#  'id prefer it when its a diversion that goes on its first mission and dies instantly and we get the real 007 who is nyongo',
#  'my favorite james bond film too good to know im in excellent company',
#  'i dont know what im doing with james bond i dont know if it makes absolute sense to start over from scratch we just did and i dont know if enough has changed since casino royale to make it worth revisiting its entire lifecycle heres what i could try if i were in charge',
#  'cant keep track',
#  'and and and',
#  'mf this is 0069',
#  'no',
#  'we see this in the many adaptations of ian flemings james bond no one can say that daniel craigs bond fundamentally takes sean connerys character',
#  'youre welcome',
#  'is really',
#  'its james bond not bloody spy kids',
#  'black james bond vibes',
#  'impossible mission',
#  'as much as i love him',
#  'politically correct this was the last bond film',
#  'hmm interesting',
#  'adani is a james bondtype villain for whom the world isnt sherry enough for greed',
#  'i like it too i dont mind if my bond films are silly i just dont want them to be boring',
#  'dudson well in that case maybe he should have said jc was worse the point is it was a tough question but if hed answered a few easier ones maybe no one would notice he fended that off he wouldnt even respond to that',
#  'the new james bond film was announced to be released in april 2020 but it was eventually released theatrically on september 30 2021 almost 15 years delay in a film release',
#  'so the circle widens and now i propose to settle this with a fight between them which is fair enough i think for james bonds role',
#  'i bet its wrong now for a white actor to play the role of the fictional character othello',
#  'shame about the end',
#  'youre pathetic',
#  'movie spy cia fbi homeland james bond',
#  'how about taking on the role of dame judi dench fully as a british woman',
#  'damn yes',
#  'we want the next farewell to 6 subway thank u',
#  'you have a short memory',
#  'come on ryan it would be hilarious d',
#  'to clarify',
#  'no time to die has given the worst ending of any james bond movie website jamesbond notimetodie 007jamesbond bond',
#  'the past isnt but he is',
#  'hon lol thanks',
#  'am i the only one who saw him die',
#  'and whine that the next james bond will be a fucking lesbian',
#  'i agree with you',
#  'ok why did no time to die have to have the saddest ending i have seen in a long time jamesbond bittersweet notimetodie danielcraig',
#  '7910 098 077 ok kiss me',
#  'nfts inspired by jb on our website',
#  'looks like moss mate',
#  'hey the next james bond this is a great idea god says you have to choose your scripts wisely cause it might destroy you like it destroyed dmx because doreen shagged better than you all come on i didnt know you liked her like i do',
#  'new episode coming in hot hot stove reaction from obiwan kenobi top 5 movies from the 80s apple website hosting spotify website hosting backtothefuture starwars batman jamesbond website hosting',
#  'and and and',
#  'it was great',
#  'thats if they want to keep the james bond role going but since they dont kill the character for no time to die',
#  'when you dont have time to worry about keeping your boat looking amazing we work closely with spirit yachts to deliver the highest quality finish',
#  'jamesbond former canadian prime minister jean cretchien has expressed interest in being the next james bond website',
#  'i think jack sparrow can keep alive',
#  'under no circumstance',
#  'yeah hes more of an austin powers',
#  'lol',
#  'i like you',
#  'i was pretty disappointed with this film i expected more',
#  'for sure',
#  'why is bill gates suddenly so interested in talking about smallpox why is the new james bond film about smallpox as a bioweapon why did the biden administration just buy 113 million doses of an oral smallpox antiviral one thing you can never say is you were never warned',
#  'lol',
#  'right',
#  'the names jam jam creative',
#  'jedi759 told me about the james bond film',
#  'but the future is',
#  'its really important i think shes just as great as him',
#  'check out what i found about funko pop james bond from the spy who loved me 522 james bond 007 website',
#  'hi',
#  'holy shit good point made in the 90 second reviews nttd will absolutely be the last time bond operates on her majestys secret service the next bond film will be on his majestys secret service when his contemporary jamesbond',
#  'look what i found',
#  'lol',
#  'ive said it before and ill say it again',
#  'they asked me to be james bond they turned it down',
#  'your protest is noted',
#  'cried',
#  'pete davidson will be dating the next james bond',
#  'no',
#  'you are ridiculous',
#  'slightly james bonds',
#  'i agree with you',
#  'dass new james bond on demand tonite sky amazon',
#  'okay i think its safe to say that everyone the next james bond wants to be alone this week',
#  'there was no need to kill this james bond could have just recast the actor and carried on as usual',
#  'every word is right here a very personal homage to daniel craigs james bond website is given',
#  'true love summer good',
#  'james bond didnt know how to handle you miss but you would be an excellent choice',
#  'i could see ryan reynolds taking the franchise back to the roger moore gadget days it was going to be so much fun',
#  'idk a canadian james bond would be a big change lol they already had an american barry nelson 1954 climax episode 3 season 1',
#  'what is the canadian version of mi6 the mounties',
#  'i hear that in the bond james bond voice saying nono no',
#  'is he making one last attempt to become the next james bond',
#  'should be john cena playing a chinese james bond',
#  'what if we threw another white cishet male sooo radical website',
#  'i mean',
#  'tom holland talks a lot about being the next james bond',
#  'omg i cant wait for the red notice sequel with ryan reynolds the next james bond and the wok john xinas boyfriend the first was a cinematic masterpiece and christopher nolan should take notes on how to make a real movie',
#  'oh nahh 007 will always be for james bond',
#  'will probably be the next james bond',
#  'hes the husband of a bodyguard wife or something hes got a fucking triple a rating for heavens sake',
#  'james bond cannot have twink energy gender',
#  'but live his style',
#  'maybe jimmy bond james bonds lesserknown halfbrother',
#  'but james bond is',
#  'not demanding enough',
#  'its not great enough when you compare it to the original anime but when you consider cowboybebops liveaction on netflix on its own its a very enjoyable space western show that feels like james bond movies in the era of roger moores and quentin tarantinos film mixed on the site',
#  'johnny canadian',
#  'ryan you would not only bring the politeness to it but also add some humor',
#  'yesterday we released our third podcast episode about james bond we talked about the development of the franchise click below to listen to notimetodie',
#  'trashfilm',
#  'consistently my 1 jamesbond film theworldisnotenough',
#  'consistently my 1 jamesbond film theworldisnotenough',
#  'the new entry no time to die is now available to stream on the uk jamesbond website',
#  'the james bond drawing night at illustrationisolation was a blast keep sharing your awesome sketches with us and watch the next live stream every thursday at 4pm pt tyler clark website is given',
#  'since when is james bond a twink',
#  'has anyone else seen the new james bond notimetodie what do you think',
#  'should be a real change to the site',
#  'lil is disappointed this time that bond has been given an emotional touch kind of a family man daniel looked better than polite',
#  'sorry you got caught on the site',
#  'can someone at skystore sky explain the 1599p fee for renting a movie in uhd hd and sd without mentioning the words pure greed jamesbond notimetodie',
#  'mine tswlm was a near perfect film in my humble opinion there were great ones',
#  'henry cavill will be the next james bondilu but sorry ryan',
#  'james bond has a whole different meaning for me now and i wish we would just let the series run its course',
#  'sean connery the only bond james bond',
#  'when you dont have time to worry about keeping your boat looking amazing we work closely with spirit yachts to deliver the highest quality finish',
#  'no',
#  'i didnt know i tweeted about the purple pitcher plant via james bond yesterday ive been hearing more about smallpox since the summer specifically june',
#  'thats actually not a bad pitch',
#  'twitter says the site is different',
#  'if that happens i would actually consider watching it',
#  '7910 098 077 awww ly sweat',
#  'they tried to get me to play james bond but i said no no no',
#  'i couldnt take the bond franchise seriously anymore any minute i waited for a crackup line of',
#  'james bond will return 007notimetodie',
#  'i like jon hamm but ryan reynolds would have been a great fletch',
#  'there is very little about dad that i dislike this sword fight is easily one of the best scraps in bond history',
#  'ryan is a female bond sheesh',
#  'i agree',
#  'bob odenkirk for james bond pass it on',
#  'why not',
#  'wb well then ryan can be her buddy',
#  'oh yes',
#  'dr no then sure',
#  'a canadian accent is acceptable',
#  'hes my pick for a soft reboot and there were bond references on the films website',
#  'a canadian bond what a brilliant insight if not a traditional bond',
#  'die another day has become quite dear to me over the last year and a half',
#  'that would require him to mean business we cant have that',
#  '7910 098 077 thats so sw',
#  'however how about playing a bond villain',
#  'oh my man this style is signature',
#  'everyone wants to be the next james bond',
#  'hahaha someone came to play',
#  'kate beckinsale is no dude my friend',
#  'pretty much so the question arises',
#  'this stuff is literally out of a james bond movie like what whereispengshuai is',
#  'you know its gonna happen',
#  'der agent deadpool 007',
#  'i would watch the movie saving wrexham from a global menace ryan reynolds wants to be james bonds next james bond website',
#  'much prefer deadpool 3 lol',
#  'its hard to go wrong here but the james bond aston martin db5 is on my mustbuy list if i ever win the lottery',
#  'this line would work if you dont turn off the bondspoiler alert at the end of the movie let me think about how to finish the next james bond film i know plastic surgery always works when youre out of ideas',
#  'but i was expecting you',
#  'how about a canadian version of bond where he says oo like oo in moo and none of the bad guys can kill him because hes too nice',
#  'the only fair way to do this is to toss all the potential actors names in the box',
#  'already has too many franchises all well deserved',
#  'it looks just like the next 007 says right now',
#  'well thats a hard no the rock wasnt supposed to be bond',
#  'danny devito for bond',
#  'i agree that bond is too serious more deadpool',
#  'wb or ryan as a badass bond girls sidekick ryan too cheesy to be a good bond',
#  '30dayjamesbondchallenge day19 if i were jamesbond',
#  '7910 098 077 i should say thi',
#  'likewise',
#  'i dont know if its related to modern directors the screenwriters jj abrams killed han solo',
#  'they werent funny reynolds is all funny',
#  'i do not know',
#  'the cast of richardmadden bond girls varies depending on the storyline in which it is played and the actual stories that have been written to date',
#  'chance93 rarely funny youve never seen connery or moore have you',
#  'bob bob',
#  'whyyyyyyy you are the best choice for the role',
#  'i think you have the opening for deadpool 3',
#  'no bond is smooth',
#  'he makes a great q',
#  'i dont want 007 deadpool without a mask love his films for the humor he brings to them',
#  'anyway ive already chosen our next bond',
#  'doing something radical is like a rocking chair',
#  'and and and',
#  'oops bad recording',
#  'pretty much everyone has seen a james bond film',
#  '0069 a better fit',
#  'and and and',
#  'sir you are too massive you could play a bond vehicle faster than james bond himself',
#  'while i worship ryan',
#  'kind of a bondaustin powers hybrid',
#  'i think it should be an unknown actor a search must begin',
#  'it wont be the same if he adds a yes to the end of everything',
#  'james bond is more real than the actors who played him',
#  'you have ruined your own essence',
#  'you just nominated yourself mister',
#  'i mean',
#  'yes yes yes ryan youre a pro lets hear you say shaken not moved in your best british accent',
#  'wb i love me a little kate maybe a badass bond girl pal of ryan',
#  'great actor but wrong for the role',
#  'just waiting for his next deadpool movie so there can be a trilogy everyone loves a trilogy',
#  'why not good',
#  'maybe cia liaison david hedison',
#  'let me finish',
#  'the guy knows he wont be james bond',
#  'quest some age difference between the two',
#  'and a weapon of choicea pez dispenser',
#  'i just noticed that ryan has a forehead shaped like an amniotic sac',
#  'ryan reynolds says hed be the next james bond if people let a canadian play the role',
#  'sorry green lanterns james bond doesnt blow dudes',
#  'this is one of the greatest title sequences ive seen from the james bond movies',
#  'maybe 00maple syrup as a canadian version of bond in a mountie suit',
#  'my first james bond theatrical adventure appeared 22 years ago on theworldisnotenough website',
#  '7910 098 077 also afterwards',
#  'according to its facebook page the toro restaurant at 1760 scottsville road opens at 4 pm today it is located in the former home of buckhead kitchen amp',
#  'please stop fooling around its been well over a week since ive emailed inquiries and am still awaiting a response all i get are more requests to resubmit the email address',
#  'the website is given to incheon ganghwagun',
#  'wellknown restaurant panda express was facing a sales slump to fix it',
#  'a book by mccalls scotland st is a copy of my 42nd st restaurant review it is defamatory as it speaks of my colt misubushi being broken into and crushed in brussels elaine garlic from oldham was at the port namur homeless center and on my eurostar train',
#  'will not be good for the restaurant and wine business',
#  'the minsk group has risen again and abandoned the “search for the best restaurant in vienna” website',
#  'i thought you knew monday through thursday',
#  'gregdickinson booster jabs now required for over 60 boosters here in greece',
#  'wolfgang pucks downtown la restaurants wp24 and nest have closed see there are positives as a result of the pandemic website',
#  'check out rivals uga and georgia tech at bobby dodd stadium on saturday',
#  'back in august',
#  '11 i do that sometimes lol',
#  'shawn was given a website at a restaurant in new york yesterday',
#  'place like in a restaurant or a trip to a country',
#  'kirstysnp and like many of that vast majority that you have contacted ie not blocked by you depend on the oil and gas industry for their jobs i include shops restaurants service businesses artisans etc because you are economical',
#  'swiggycares i spoke to him and told him to deliver then his number was unavailable',
#  'local favorite restaurant family style commercial conversion',
#  'who wants you tested to enter now all you need is a mask',
#  'ncoelotd wow that was a nice day shift at our local restaurant huh old sport',
#  'every pasta restaurant recommendation',
#  'shoutout to our coalition members',
#  'realdonald trump would like the chicken nuggets meal with a side of fries and a little cocacola website',
#  'i will visit the restaurant before next week im looking for specific things to do there than i can only find in vegas ive already bought a ticket to jump out of the stratosphere next friday but thats all i have planned so far',
#  'left this note exactly 2 years ago in a restaurant in sampaloc uwu manifests it on the rphs website',
#  'visit our chelsea restaurant of the month pizza express pheasantry live music and fabulous pizzas in an elegant venue in the basement of a historic building on chelseas kings road great gifts and 20 offpub tokens',
#  'we are hiring a senior service manager for a fine dining restaurant in houston',
#  'i need some general chicken and veg tsos in my life but the delivery charge is too high and i dont feel like going to the restaurant to get it later',
#  'uticaeric greenwald is the guy who can eat at the best restaurant in the world',
#  'i dont like listening to louis armstrong in new orleans and sipping black coffee too bad none of the restaurants were open',
#  'i remember talking to doctors about a year ago who were devastated about the arizona storm before the vaccine because they knew it would mean thousands of deaths and hospitalizations but nothing was done to alleviate except heaters for restaurants',
#  'polls by antovolk yougov have always shown that the public supports vaccination certificates',
#  'a nice cup of tea and carrot cake to end a super lunch cheam the staff are always so friendly',
#  'lrt thats funny because my island always makes ketchup so i made her the chef at my resort restaurant too haha',
#  'you return the beaming smile as you enter the restaurant a waiter comes',
#  'please take care of yourself and others stay safe from covid19 wear a face covering in busy places amp',
#  'we can also take you to shops and restaurants whose managers can speak english we hope you will find it convenient',
#  'a weird thing about being an exfamp',
#  'wellknown restaurant panda express was facing a sales slump to fix it',
#  'amusement village with distillery',
#  'she knows everything about these restaurants',
#  'haechan ended up catching the fish from the restaurant because he couldnt catch any on the marine website',
#  'there was no massive labor shortage just a shortage of employers willing and able to pay and treat workers fairly',
#  'local restaurants are showing the football game so join other alumni and friends to cheer on the ichabods iron rail brewing 705 s kansas ave johnnys tavern topeka 2821 sw fairlawn rd the pennet 915 s kansas ave skinnys sports bar amp',
#  'local restaurants are struggling to find workers in the wake of the pandemic but its not just the fast food industry thats struggling',
#  'fresco restaurant pizza amp',
#  'my friend asked me to go out today and i said yes and we went to this amazing restaurant next to the unique candle or lamp on each table',
#  'hello britain',
#  'the december 2021 issue of southside magazine is available now its our christmas markets with illuminations wreath making and our gift guide and meeting the winners of westside restaurant amp',
#  'wellknown restaurant panda express was facing a sales slump to fix it',
#  'of course',
#  'every day stories yesterday a small restaurant got 350',
#  'oooh',
#  'coronation chicken terrine',
#  'try brisko restaurant after union bank for pz',
#  'p86 compulsory vaccination for all',
#  'my restaurant name will be shitty ingredients',
#  'hello rohit',
#  'congratulations on her luck in receiving her deep connections and knowledge of the restaurant scene website',
#  'enjoy the best of sydney harbor at this worldclass address',
#  'looking for a restaurant in cebu with event space',
#  'golly',
#  'while its pretty funny that chefs lose their minds when it comes to having their restaurants rated by a tire company ingroup ranking systems rule everything around me',
#  'where exactly does half the sandwich come from will you give me half of someone elses sandwich',
#  'nobody said you should exclude them from your social circles apparently they took his statement personally people living in extreme poverty do not expect their friends to attend birthday dinners in restaurants',
#  'we are hiring an experienced multiunit director of operations for mexican restaurant websites hiring jobs in houston',
#  'new tough rules for bavaria in bavarian corona hotspots with a sevenday incidence of more than 1000 public life is to be shut down over a large area restaurants sports and cultural facilities there have to close and events have to be banned',
#  'they have everything you need to eat in a top class restaurant but no oo my boys i love them be humble emmarose',
#  'websiteisgiven websiteisgiven fun village with distillery',
#  'do you know why airport transit lounges dont seem to have enough seats heres why behavioral science airport operators do it the way you sit down',
#  '3 a cinema concession stand',
#  'hmmmm frida i think its a mexican restaurant',
#  'dirtyjesus ooh boy it means youre not married yet trust me its difficult bro live with one then these many again youll be a dead man in no time',
#  'augustbythepond i hope you get it it seems like the dlc added at least one new villager to me every day',
#  'i could only agree with eric adams that the ban on propane heaters needs to be lifted alfresco dining in winter is cold and restaurants will suffer',
#  'speaking of food do you know what time youre playing at alices restaurant on thursday i need to plan my menu prep accordingly as my daughter says when does this crazy song play so we can make stuffing a tradition',
#  'shawn was given a website at a nyc restaurant yesterday',
#  'dont you just love chinese food restaurant bans chinese from allyoucaneat buffet for eating too much',
#  'divers the castle and chain bridge there is also the gundel restaurant but it may be closed excellent traditional food and gypsy violins',
#  'which restaurant',
#  'grab the restaurant',
#  'the challenge lies in the settings where transmission is most likely',
#  'reminder our 20 allyoucaneat brunch buffet is tomorrow website is deployed we remind you that our brunch buffet is tomorrow',
#  'nov 19 specialsbutter chicken on basmati rice amp',
#  'i have to make a hair appointment today because apparently im going to a nice restaurant for thanksgiving and my mom is going to blow me up when she finds out my hair is bad',
#  'they wouldnt let me host a diners driveins amp',
#  'nolore retail booster',
#  'help my family just planned a family dinner at a restaurant',
#  'javiergoya7 my family has been in the hospitality industry for 70 years we have been waiting for a single site hvac unit for over 7 months we have been waiting for a deep fryer for over 6 months',
#  'isback have you listened to bookworm 2s connection between bot sentinel',
#  'amanda martinez texas karen who threw hot soup at restaurant workers was arrested on smartnews website',
#  'shawn mendes at a restaurant',
#  'during our visit to najd village heritage restaurant in riyadh',
#  'we are hiring an experienced multiunit director of operations for mexican restaurant websites hiring jobs in houston',
#  'im on my way to berlin and im so excited about the msian restaurant lmao',
#  'if you were to sit in a restaurant with a famous celebrity who would it definitely be mine is adil ray',
#  'matter18 booh nonconformity thanks you are absolutely right thats why i spend a lot',
#  'i also tried to reach your supplier and your restaurant but no one answered my call',
#  'the margaritas from the mexican restaurant take you there every time i amp',
#  'find out about restaurant and shop openings',
#  'i congratulate and commend the hotel for its excellent standards despite the difficult covid times i also recommend sizzlers restaurant on the diani website for succulent steaks',
#  'if hello if',
#  'z56cjt how about travelling',
#  'why would you take me out on a date at my boyfriends restaurant',
#  'lexathecoolkid there is a restaurant near me that offers romanian food',
#  'robicellis too lol i will be in baltimore next week and can explain them but i need those',
#  'kind of sucks that covid has had a profound impact on restaurants and i dont know what it was but the last three seats ive been to i personally felt like i can do better and i cant cook for shit',
#  'shawn mendes was given a website at a restaurant in new york yesterday',
#  'likewise',
#  'this restaurant i went to once served us cornbread with literal corn in it and im really traumatized',
#  'chicago a thinly sliced \u200b\u200broast beef sandwich topped with sautéed peppers hot or sweet all dipped in the beef cooking juices',
#  'hallo francesca',
#  '5 restaurants in denver offer thanksgiving takeout find out which ones',
#  '5 restaurants in denver offer thanksgiving takeout find out which ones',
#  '5 restaurants in denver offer thanksgiving takeout find out which ones',
#  '5 restaurants in denver offer thanksgiving takeout find out which ones',
#  '5 restaurants in denver offer thanksgiving takeout find out which ones',
#  '5 restaurants in denver offer thanksgiving takeout find out which ones',
#  '5 restaurants in denver offer thanksgiving takeout find out which ones',
#  '5 restaurants in denver offer thanksgiving takeout find out which ones',
#  'have you heard anything about what happened outside of your restaurant today no what happened',
#  'i finally decided that i dont believe in tipping its not my fault that companies underpay and everyone just saves it because theyd be in a damn position to take it so i am amp',
#  'the boy in the striped pajamas has never cried in any other film',
#  'like a protagonist from a movie',
#  'and he stripped in the credits of the dbs movie',
#  'did anyone remember this movie website',
#  'im wondering why the soundtrack was released before the film i thought they were usually released after',
#  'could be the setup of a magically realistic heist movie or a plot point of a kojima game that you expect to accept without question',
#  'i am beyond excited and super proud to be a part of the female gaze a film poster project with over 30 talented female artists organized by the brilliant posters thank you eileen',
#  'it was a beautiful and heartwarming film everyone was great and i loved them',
#  '1 too',
#  'honestly both movies arent as bad as people claim',
#  'population control you watch all those old hood movies but dont take any shit with you',
#  'the only way dc movies make a profit is to save on the lighting bills',
#  'it will take a while to explain this one in the movie brother bear there are these two comic relief mooses voiced in the portuguese dub by the famous portuguese comedy duo toni amp',
#  'watching the batman trilogy because christopher nolan movies are super interesting and batman is a great character',
#  'my absolute favorite movie still the king',
#  'only one week until this becomes a vacation film account what are you most looking forward to',
#  'virtue ghostbusters afterlife critics signal it was too much fan service is it bad to give the fans what they want then who the hell are these movies for the nonfans who are activists disguised as reviewers',
#  'gal10 kountrygirl thank you terry hav',
#  'leo is friday',
#  'i was a little surprised not to see adam on the red carpet at the gucci film premiere in la last night',
#  'its not just buy and hold we need to invest in our business go to the movies and buy food and drinks not to mention buying with crypto just to say',
#  'i also got netflix ready if they need better movies',
#  'holy holy holy man next to a wes anderson movie this is one of the greatest lineups of all time',
#  'can star in my movie im going to make if blows you boys dont miss it early before that ship to the moon takes off pandagirltoken pandagirl pandagirlmoon',
#  'love this movie',
#  'and',
#  'my sister is watching an hp movie and this one death is so sad',
#  'the one piece creator reveals the first details of the next film in the series',
#  'i was given a website after watching a brian de palma film',
#  'some denzel washington movie',
#  'i saw love birds on netflix last night',
#  'suspect boris realized they could keep quiet for their old pal',
#  'rewatch the sopranos or the wire or mad men or the west wing or succession',
#  'impressive',
#  'house of gucci has been trending for a whole week or more',
#  'a good reason to keep going to the cinema instead of watching a movie on tv at home is given the netflixfilms website',
#  'okay',
#  'oh you are so cute i need you in a movie not nwh together asap',
#  'ghostbusters afterlife is this weeks mustsee movie we had a blast on opening night last night you can see the iconic 2016 ecto1 again this sunday afternoon from 3pm in our greatyarmouth car park before the matinee film is released',
#  'depends on my mood but recently movies hwasa our pride 4daystillguiltypleasure',
#  'its like the live action re movies that could be really fun but stressful and i dont need that in my life right now xd',
#  '13th warrior is one of my alltimes',
#  'house of gucci is another american film',
#  'being a prabha fan is not easy 23 years waiting for a movie no timely updates no perfect photo shoots no professionals',
#  'were getting a onepart film on shanks',
#  'mcgone gillettes short little man for an antman movie',
#  'my excitement has reached its peak',
#  'end the day on the couch',
#  'it was a nice movie and you could see the struggles of the poor but now youre just telling me that the rest of the poor people were lazy which isnt true the myth of meritocracy is one thing',
#  'i hate how i watch movies to sleep sometimes it takes me 35 business days to see a movie lol where shang chi looked cold',
#  'when remaking a movie or tv show should the original be destroyed dont need two entries taking up space',
#  'thank you to everyone who tuned in tonights baduypride episode on brendan frasers colorful filmography it was a fun little trip and looks like we have a lot of movies to watch on the site',
#  'awesome its quite a depressing movie',
#  'no bc help grandma how should i add the movies to my list or whatever',
#  'i love how in horror movies the character asks if anyone is there as if the killer is saying oh yes im in the kitchen do you want a sandwich',
#  'i pledge my allegiance to teamgalgadot ready to fight for the rarest artifact rednoticetreasurehuntgood movie',
#  'lol',
#  'the clowning of the year do a whole countdown',
#  'yall i keep seeing scenes from the colin kaepernick movie and they piss me off white people if you want to procreate with black people dont secretly hate us too',
#  'done bhai your film will be a super duper hit',
#  'manuel paused the movie because i cant stop freaking out on sunday cant think of a more perfect interpretation of this number crying and smiling alike',
#  'official very true bewithme by dimashqudaibergen is a great song that has all the pop elements in it',
#  'free time to enjoy ghostbusters afterlife ghostbustersafterlife ghostbusters ecto1 xbox20 xboxshare weekend movies website',
#  'i think i saw the whole movie in the trailer',
#  'jawn finally solve the problem with cinema popcorn its not wet enough',
#  'one of my favorite bts hk stories is about this film which ringo lam expected cyf to build up for the role',
#  'what the ngamshishis call a popocorn movie',
#  'reading crime novels and watching horror movies how but in reality i get scared easily i have a thing for pretty cute things pink i love you im a pink lover i love pink wehavegaeul ive',
#  'ha im in the same mood at the moment i recommend adding a hallmark film to the mix',
#  'he was one of the best parts of the movie he was a bloody dog',
#  'do you like to read the book first or watch the film',
#  'back again limitless boldness and ignorance i would at least avoid them they want to be brave at least for the weekend until they forget the film and racism again',
#  'from the sevenhour satantango to terrence malick movies',
#  'serizawa from the crow movie',
#  'super movie congratulations so unique',
#  'look i think thats a great movie concept with the best batman but what matt reeves batman has to offer is more interesting excuse me',
#  'ovivolp eva green one woman one smile 17 movies websiteisgiven',
#  'i love it when a movie uses humor like the way you wave a toy in front of a baby every time it starts sniffling',
#  'loki was really good but thats because theres just a lot of character development and inroom conversation its nowhere near the movielevel production we were promised',
#  'this data shows that extremes today are far beyond historical experience extreme heat and extreme precipitation are increasing disproportionately',
#  'and germany had the second most expensive disaster in 2021',
#  'meanwhile satellites from global observation networks continuously measure all incoming and outgoing radiation 000 scientific studies on climate change come out every year 22',
#  'our article on the cognitive evolutionary foundations of human communication is out',
#  'my dogs name is minton today he ate my shuttlecock',
#  'sometimes we choose pain people are quick to whip themselves but these acts affect not only the people doing them but also those watching in todays episode i explore the benefits of ritualized suffering with',
#  'update now available for preorder',
#  'politics and politics from across the political spectrum with changing voices',
#  'reminder new postdoc position at the university of toronto',
#  'this article forthcoming in cognitive science began as a suggestion for franks devpsych class during the tf ryousif',
#  'our lab is hiring',
#  'former new york times journalist chris hedges on the israel lobbying campaign to get cornel west out of harvard university',
#  'funfact2 one year later',
#  'funfact when i was only 4 years old',
#  'a strong us winter storm brings heavy snow to parts of the lower great lakes',
#  'charles mcgee he flew a total of 409 combat missions during world war ii as well as the korean and vietnam wars',
#  'the philippines is grappling with a record surge in covid cases appear milder than previous outbreaks and hospitals are not yet overwhelmed',
#  'broadway producers have found a way to keep shows running amid the surge in virus cases',
#  'the fbi identified a british national as the man who took hostages at a synagogue in texas on saturday he was killed during the rescue operation british authorities have confirmed that antiterrorist police are involved in their investigation',
#  'countries like serbia',
#  'marine le pen fought for power in france with fiery rhetoric for a long time but she heralded the final spurt of her third presidential election campaign with a video speech',
#  'in south africa you cannot criticize the judiciary',
#  'more than 1 according to a washington post investigation of censuses and other historical records',
#  'three dead in suspected drone attack on uae capital',
#  'the fbi investigates a texas synagogue attack as terrorism as britain takes two teenagers into custody',
#  'perspective neighboring families have sons who sometimes play together',
#  'more than a thousand parishioners packed the blocks in front of the bronx islamic cultural center on a bitterly cold sunday morning',
#  'last sunday including eight children the youngest victim was 2 years old and the oldest 50',
#  'texas synagogue kidnapper identified as 44yearold brit',
#  'more than 150 million trees are planted in finland every year they have banned forest destruction since 1886 and more than 75 of the countrys land is covered',
#  'according to canisius college researchers women have a better nights sleep when they sleep next to dogs than men',
#  'experiencing goosebumps while listening to music may be the result of a different brain structure people who get goosebumps from music tend to have more fibers connecting their auditory cortex to the areas responsible for emotional processing',
#  'the phrase i have a bad feeling about this has been said in every star wars film',
#  'experiencing goosebumps while listening to music may be the result of a different brain structure people who get goosebumps from music tend to have more fibers connecting their auditory cortex to the areas responsible for emotional processing',
#  'music has been shown to lower stress hormone levels',
#  'saturns moon titan has such a dense atmosphere and low gravity that you can fly through it by flapping any kind of wings attached to your arms',
#  'breaking floods in santa cruz california as a result of a tsunami caused by the eruption of the tonga volcano a tsunami warning has been issued for the west coast of the usa',
#  'earth information provides evidence of the climate challenges we face and informs possible solutions and whether policies are working join me at cop26 or online this afternoon to see the uk website perspectives on earth information for climate action',
#  'defra is today publishing our consultation response on crop and livestock geneediting a cautious approach that will unlock the scientific potential of genetic engineering to improve the health resilience and environmental impacts of the food system read it here',
#  'todays ipcc report once again confirms the great challenge of climate change mounting evidence of links to extreme events and sea levels highlights the need to transform society read the csas views here',
#  'this is a nice summary of the greenhouse gas removal demonstrators announced by news today',
#  'nature can be used in many ways to remove co2 from the atmosphere new newsfunded projects launch today to rigorously test five approaches in the field the results will be very relevant for thinking about how best to reach net zero',
#  'an independent report on the leadership of the g7 was published by nick stern it illustrates the importance of environmental sustainability and resilience for successful future growth sound advice for g7 leaders ahead of their meeting in carbis bay read it here',
#  '2021 was the fifth warmest year on record and the past seven years have been the seven warmest years on record',
#  'a new preprint review we cowrote in which we consider the implications of dualbodyism for the flys sense of self and consider the sublime transformation of metamorphosis as a gateway to the promised land of comparative circuit neuroscience',
#  'silencing machinery to restrict small rna amplification to transcripts selected by argonauts for longterm silencing site gives rnaspecialissue condensates',
#  'a british computer scientist recently invented a test of computer rendering technology where you have a photo of a real piece of jewelry under controlled lighting conditions and then render a similar object with a ray tracer and ask people to pick which one is real',
#  'only 1 in 5 alevel physics students is female a number that has remained unchanged for the past 20 years',
#  'dart will reach the didymos system in october 2022 and impact dimorphos the impact is expected to change the orbital period of dimorphos around didymos by up to 10 seconds which can be accurately measured',
#  'this will allow scientists to determine how efficiently the collision imparts momentum to the target rock this information will be crucial in designing missions that could deflect a possible future earthimpacting asteroid',
#  'launcherone payloads should now eject from the upper stage',
#  'the falcon 9 second stage has just performed its second burn to circularize the orbit the deployment of the satellites will begin in a few minutes',
#  'falcon 9 stage 1 has landed on lz1 at the cape and stage 2 has entered nominal elliptical parking orbit second burn for the second stage at 1620 utc',
#  'a source advises me that the shi jian 21 satellite which ended maintaining its position with its subsatellite on dec 26 rendezvoused with a defunct beidou 2g2 navigation satellite object 34779 from dec 26 to jan 8 had the beidou satellite drifted away from the station back in 2010',
#  'another north korean missile test at 2227 utc 10 jan no further details yet',
#  'nasa prepares for launch of suborbital flight nasa 36363uh from wallops island at 0500 utc the black brant ix rocket will carry the us dxl 4 payload several hundred kilometers up from miami to study xrays from the hot interstellar medium',
#  'satellites detect large methane emissions from landfills in madrid the gas was released at a rate of almost 8800 kg of methane per hour from two different sites in august 2021',
#  'spacex launches 105 satellites from florida',
#  'the change5 lander makes the first onsite detection of water on the moon',
#  'airbus is developing the energy management and distribution system for the key module lunar gateway',
#  'gilmour space kicks off australias largest rocket engine test for 2022',
#  'the james webb space telescope should have fuel for about 20 years of science',
#  'amazing milestone as nasa fully deploys the webb telescope in space',
#  'spain authorizes the creation of the spanish space agency euro weekly news',
#  'irans simorgh rocket once again fails to reach orbit',
#  'the webb telescope successfully unfolds the decisive sun protection',
#  'electron microprobe analysis markers all day at the cathedral of and all evening in preparation for tomorrows antmets morrrclassificationssoon',
#  'icymi the first nine meteorites from the expeditions were classified as common chondrites h6 l3 l5 l6 ll6 according to their iron content h l ll and degree of heat processing',
#  'over 200 participants from around the world for volcin germanys melts glasses magmas 2020 online course follow mgm2020 all week for more',
#  'mineralogists found the first natural occurrence of the iron carbide mineral scottite',
#  'neuroscientists know that the retina can sense movement but it took a citizen science brainmapping game to figure out how to do this',
#  'heterochrony or changes in the timing of developmental events explains some of the differences in appearance of a newborn kangaroo and a human read more about the evolution of these processes',
#  'as droughts caused by global climate change become more frequent termites may play an important role in helping rainforests survive the dry conditions',
#  'using 3d tomography scientists can isolate both vertical and horizontal slices of the mantle catherine clabby explains the process of acquiring seismic data to look inside the earth',
#  'over the past 40 years researchers have learned that social relationships can mean life or death for young primates',
#  'researchers have uncovered the earliest known examples of figurative art the drawings were found in remote karsts in borneo and are more than 40000 years old',
#  'dark energy is pushing galaxies apart could this gforce lead to the universeending big rip',
#  'contrary to popular belief adult human brains do not appear to form new neurons in the hippocampus',
#  'using lasers on lowflying planes archaeologists can map previously unexplored places and calculate how many people inhabited them',
#  'read the independent research by dr snow on brain formation in his unifying hypothesis of alzheimers disease published in frontiers in aging neuroscience request a personal copy from infocom',
#  'researchers are not only decoding the what and where of a memory memory in the brain but also the when',
# ...
#  'kate mckinnon plays carole baskin in the peacock series joe vs carole out march 3',
#  'america in crisis first opened in 1969 at the riverside museum in manhattan a new exhibition of the same name brings together historical photographs from the original 1969 project and more recent work from the past two years',
#  'the percentage of the adult population not working for covidrelated reasons tripled between december and january according to goldman sachs',
#  'the past 22 months have forced many companies to halt work and keep talent remote this means that some workers who are just entering the job market have never worked in an office met coworkers in person or commuted more than a few feet',
#  'a texas federal judge on friday blocked the biden administration from enforcing a vaccination mandate for federal employees dealing another blow to president joe bidens campaign to increase the countrys lackluster immunization coverage',
#  'priyanka chopra and nick jonas have welcomed their first child',
#  'commander billie farrell just became the first woman to command the uss constitution in the historic warships 224year history',
#  'a top womens handball team in germany says they are sticking together after two hidden cameras were discovered in players dressing rooms earlier this week',
#  'more than 333000 silicone pacifiers available on amazon have been voluntarily recalled by the retailer following reports that the teat could become detached and cause choking on infants',
#  'a united airlines flight to tel aviv turned around midflight on thursday evening due to unruly behavior by passengers',
#  'volunteers have rescued a runaway dog \u200b\u200bfrom dangerous mud flats by luring him to safety with freshly cooked sausages tied to a drone',
#  'at least 17 people have been killed in a gas explosion in western ghana after a motorcycle collided with a vehicle carrying explosives',
#  'at least 70 people were killed and more than 130 injured when an airstrike hit a detention center in yemen on friday msf said as the saudiled coalition continued to ramp up its deadly offensive against rebels in the wartorn nation',
#  'three major new studies from the us centers for disease control and prevention underscore the importance of a booster shot to provide the best protection against the omicron variant coronavirus',
#  'louie anderson an emmywinner whose career has spanned from standup and game show hosts to starring roles in television and film died friday in las vegas of complications related to cancer his publicist confirmed to cnn he was 68 years old',
#  'judge brenda penny ruled against a motion by the elder spears for britney spears to put money from her 60 million estate in a reserve to potentially cover legal fees which would include her fathers',
#  'tech giants are spending billions as they struggle to master the next big thing regulators should resist the temptation to take action too early',
#  'automation could actually help a company become more profitable and thus expand leading to a hiring frenzy',
#  'much of the eus foreign policy consists of responding to crises but europe makes its job all the more difficult when these crises are provoked from within',
#  'in the last three years the tech titans have acquired over 110 companies according to pitchbook many have invested in companies developing cuttingedge technology',
#  'overall todays gun owners are still mostly white 73 and male 63 but they are diversifying',
#  'chinas government has become aware of the danger that its overzealous efforts to contain the housing market could hurt the economy she should now come to the same realization as she is fighting the pandemic',
#  'alan jope ceo of unilever sees the future of consumer goods in health and hygiene products rather than food',
#  'government capital combined with access to plenty of public data has helped turn chinese ai firms into powerhouses in certain niches',
#  'as brexit sparked fears that the european union was falling apart emmanuel macron placed europe at the center of his political identity',
#  'in egypt the government of abdel fattah alsisi is renovating jewish cemeteries and what was once the middle easts largest synagogue',
#  'benefits such as health insurance leave and pensions are distributed unequally',
#  'fasting is not just a humiliation or denial it is a reminder of the value and joy of food',
#  'even with certain advantages russia would have trouble occupying the capital let alone all of ukraine a country about the same size and populous as afghanistan',
#  'hong kongers have a long tradition of protesting',
#  'a new study in mice suggests that a morning workout has very different effects on metabolism than the same workout later in the day',
#  'munzir el nezzel lost his leg in a bomb attack in syria',
#  'hardy kruger the first german actor to become a hollywood star after world war ii died on wednesday at the age of 93',
#  'lisala folau 57 survived swimming in the ocean for 26 hours after an underwater volcanic eruption sent a tsunami hitting his home',
#  'some smart home devices like light bulbs and thermostats can help reduce energy waste while saving money',
#  'here are 11 new books recommended by the new york times critics and editors',
#  'pennsylvania state police said a pickup truck with an enclosed trailer full of 100 monkeys collided with a dump truck and four of the monkeys escaped',
#  'two new york city police officers were killed in a shooting in harlem on friday officials said',
#  'booster shots of the pfizerbiontech and moderna vaccines not only reduce infections with the highly contagious omicron variant but also keep infected americans away from hospitals data released friday by the cdc shows',
#  'a federal judge on friday handed six university of florida professors a crucial freedom of speech victory ordering the university to stop enforcing a policy that barred them from providing expert testimony in lawsuits against the state',
#  'peru is asking for international assistance to deal with an oil spill off the coast of lima caused by a tsunami following the eruption of the tongas volcano nearly a week ago',
#  'the biden government is suspending 44 flights by chinese airlines to the united states',
#  'opposition to pet vaccines has grown in recent years fueled by an antivaccination movement in humans that has spread to animals',
#  'vladimir putin is taking the biggest risks of his career to win back russias lost glory and make amends for perceived past hurts',
#  'scientists have found a rare and pristine 2mile stretch of coral shaped like rose petals off the coast of tahiti',
#  'the poconos a historic pennsylvania recreation area is seeing an increase in home sales and demand as city dwellers take advantage of one of the last affordable lakefront retreats within driving distance',
#  'rachel stuart baker and paxton baker minority owners of the washington nationals are offering a home with a professional gym and a dressing roomstyle bathroom for 2395 million',
#  'brian laundrie claimed responsibility for the killing of his fiancée gabby petito in a notebook found near his body the fbi said on friday marking the end of a murder investigation that drew national attention',
#  'two canadian tourists were killed and another injured by a gunman at a fivestar hotel in mexicos caribbean strip on friday local authorities said',
#  'us in talks with qatar over gas supplies to europe in case of invasion of ukraine',
#  'the beijing winter olympics pose a challenge to chinas zerocovid policy',
#  'civil servants are facing increasing pressure to return to office in england',
#  'rapid covid test makers scramble to meet overwhelming global demand',
#  'southamptons new billionaire trades one football fight for another',
#  'boris johnson is trying to bolster his support among tory mps',
#  'travel companies prepare for a surge in bookings as the day 2 covid test kit is scrapped',
#  'these are the countries where social media sites like twitter facebook and tiktok are banned',
#  'in a blind tasting stem cellgrown meat tasted just like chicken but without the fat that makes chicken taste really good',
#  'with the state of the world in the hands of big business some leaders believe doing good can pay off',
#  'new dart bus routes start monday with free rides for a week',
#  'energy transfer agrees to supply gas to vistras power plants',
#  'jury convicts united development executives of misleading real estate investors',
#  'graffiti art at giga berlin',
#  'more than 200 million americans are vaccinated',
#  'notre dame cathedral has existed for more than eight centuries',
#  'a century ago there were only dozens of these tigers left in the wild',
#  'photographer alessandro cinque documents the plight of four million alpacas in peru  more than 70 percent of the worlds alpaca population  as climate change threatens their mountain pastures',
#  'with their charismatic tuxedo looks and unique mating rituals penguins are among the most beloved creatures on earth',
#  'scientists once found fossilized remains in southern new zealand that they believe came from a 220pound ancient species of penguin that stood about five feet ten inches tall',
#  'many sudanese are turning to three millennia of cultural history to build a new identity  one that balances ancient african heritage with the arab influence of recent centuries',
#  'teachers in england share their experiences of returning to school',
#  'how a muslim dating app made a british mans search for a woman viral',
#  'coronavirus live japan and taiwan report omicron surges ireland lifts restrictions',
#  'chris boardman leads new walking and cycling association in england',
#  'hermès is suing american artists over nfts inspired by its birkin bags',
#  'kyle rittenhouse is demanding the return of an ar15 rifle used in kenosha shootouts',
#  'western australia tries to contain perth covid cluster as greg hunt refuses to condemn border decision',
#  'the irishman faces 20 years in prison after exposing himself on the flight to new york',
#  'monkeys escape after truck carrying 100 animals crashes to us lab',
#  'two canadians killed after tourists shoot at mexican beach resort hotel',
#  'police are hunting a gunman after two canadian tourists were shot dead at a luxury hotel in mexico',
#  'mum cursed for calling her gen z daughter selfish for not having kids',
#  'a new device could help blind people see in infrared',
#  'the xbox series x is in stock at argos starting today',
#  'merrill lynch executive arrested on video after racist attack on store employee',
#  'husband divorces wife during wedding party after song sparks family argument',
#  'emma thompson talks shooting full frontal nude scenes at the age im',
#  'billions of dollars have been wiped off netflixs value after wall street was shocked by the groups faltering subscriber growth',
#  'airlines are demanding the government rule out future covid border closures',
#  'the delivery driver drops the food off at the wrong house and tells the customer to go get it themselves',
#  'airlines are being forced to operate more flights to avoid losing airport slots',
#  'celebrity endorsements influence only 4 fashionistas according to survey',
#  'adele surprises fans with facetime calls after postponing her las vegas stay',
#  'netflix could lose 750000 uk subscribers as disney takes control of hit shows',
#  'court of appeal to challenge media ban in prince philips will',
#  'archaeologists have uncovered what they believe to be the oldest known mint that massproduced shovelshaped miniature bronze coins some 2600 years ago',
#  'surprising discoveries in fossilized feces shrew brains and a coffeecovered rainforest are just a few of our most popular breakthroughs this month',
#  'meet the southern ground hornbill the biggest of them all',
#  'the archipelago has staked its future on the construction of an artificial raised island that could house much of the population of nearly 555000 people',
#  'in the two years since the cdc confirmed the first case of covid19 in the united states the us death toll has surpassed 860000 more than 2000 have died every day for the past week',
#  'determining the foundations of the himalayan range is crucial to understanding the local seismic risk that threatens the hundreds of millions of people who live in its shadow',
#  'the pandemic brought 75 musicians together to record an album virtually  and bring hope in challenging times',
#  'in this image by photographer paul nicklen a humpback whale shows its tail before diving in antarcticas gerlache strait',
#  'the environmental impact of certain foods has been researched for more than a decade however this study identifies which individual foods have the greatest impact on the air pollution that causes asthma heart attacks and strokes',
#  'a familyrun chocolatier has claimed ms copied the perfect match valentines day gift',
#  'patrick mahomes is just one game away from his super bowl shot but only after he was seconds away from losing in one of the most dramatic games the nfl has ever seen',
#  'bbc4 is at risk as the company scrambles to fill a £15bn funding gap after its license fee was frozen for two years',
#  'it is a pilgrimage that has been going on for almost a year the queen returns to sandringhams wood farm for the first time since philips death',
#  'ministers have been warned they will face recordbreaking gas and petrol prices in the event of a russian invasion of ukraine',
#  'russia is exploring multiple avenues to destabilize ukraine and overthrow the prowestern government the united states warned about yesterday',
#  'silvio berlusconi has withdrawn from the race for italys next president amid reports of the former prime ministers growing health problems',
#  'two cabinet ministers have called for an inquiry after nusrat ghani said she was told her sacking as transport minister in early 2020 was because of her faith',
#  'removed statue of theodore roosevelt as symbol of progress from museum stairs',
#  'the bbc said the news was overwhelmingly in the public interest but government sources told the daily telegraph that exposing the spy could put lives at risk',
#  'ireland lifts most covid restrictions today',
#  'coast guard audio call reveals reality of migrant rescue missions in channel',
#  'adele thanked fans on twitter your kindness and love tonight is overwhelming reads the goal',
#  'the brewdog boss has been accused of intimidating former employees ahead of the airing of a documentary next week examining claims of a toxic work culture',
#  'a times investigation has revealed that branches of leading british private schools in the middle east have flouted rules designed to stop homophobic bullying',
#  'officials have been told all desks in whitehall must be manned from next week as ministers order them back into the office',
#  'joe biden is considering sending several thousand troops to the baltics and eastern europe along with warships and planes',
#  'black bears are being killed in record numbers in california new data shows as wildfires force them onto busy roads in search of food',
#  'boris johnsons plan for workers to return to their daily commute is in jeopardy as rail operators run pared down train schedules until the end of february',
#  'boris johnson has ordered a cabinet office inquiry into nusrat ghanis allegations of islamophobia',
#  'police officers guarding downing street were interviewed by sue gray for the partygate inquiry',
#  'a jury has criticized police and prosecutors after acquitting a private school teacher accused of sexually assaulting a teenager',
#  'former model katie price faces possible jail time after being accused of abusive texting of her exhusbands partner',
#  'almost twothirds of the public supports scrapping the bbc license fee as the vast majority claim it offers poor value for money an exclusive poll has found',
#  'deputy prime minister dominic raab said on sunday it was extremely unlikely britain would send troops to the front lines']

# %% [markdown]
# ## Add back-translated to original

# %%
flag=0
text1=inText
len(text1)
# Out:
# 844

# %%
if flag ==0:
    text1= inText+translatedList
    flag+=1

text= text1
print(len(text))
text
# Out:
# 1688
# ['   does canada have its own spy agency lol they send him undercover to stop the japanese mafia from selling imitation canadian bacon in a hot fuzz style movie',
#  '   yes i dont want ya as james bond',
#  '   we all love ryan but hes canadian and instead of killing the baddie he would try to talk them down by being nice',
#  '   you woud make a great james bond but you would have to change the gin for martini',
#  'he looks like an agent or kingsman type of shit in 2nd go james bond go james bond go go go go',
#  '   i agree with ryan reynolds i like the tradition of having english actors play bond and a truly controversial actor is someone like idris alba its time',
#  'disappointed with the new jamesbond movie its like they killed the franchise',
#  ' james bond dies at the end of the movie last line in the credits',
#  'watched the latest last james bond movie at this amazing cinema  last weekend    art direction and styling rud  hair and makeup   models official      websiteisgiven',
#  '   beautiful photo',
#  'has anyone ever set a timer on their  amazon alexa for 6 minutes only to have it end after 3 minutes asking for a friend    jamesbond  websiteisgiven',
#  ' worst bond movie ever',
#  ' yes everybody loves ryan',
#  '   yes yes yes',
#  'hey  why not make your own new james bond series',
#  ' nah',
#  '   are yall mad  the only logical direction is the jinx seriesaint gotta be  unless she want 2  she a pretty good director toolets go  websiteisgiven',
#  '   no',
#  ' who is that man james bond',
#  'congratulations capt william h wiley amp',
#  '   he would make a good q though admittedly ',
#  'discover the link between the vegetable broccoli and james bond  websiteisgiven',
#  '   7910 098             077    mr 007 is ',
#  ' the ending was a bad decision which i say the producers will come to regret i mean brosnan got to finish up in bed with halle berry',
#  '   yes yes yes',
#  '   more bean than bond',
#  'watching james bond tn ',
#  ' i spent 18 to see no time to die',
#  '    oops spoiler alert  youve gotta watch the rest of the infinity saga',
#  'when i was in high school 9years ago thai fans call the comeback of adele when she put skyfall as a soundtrack of james bonds film  adele tornado ',
#  '   oh cmon  i bet you do a wonderful british accent',
#  'im open to offers selling my 1953  safins mask ',
#  ' i thoroughly enjoyed notimetodie ',
#  ' i dnt see tom  doing another spidey movie',
#  'bonus episode  listen now  weve unlocked our first patreon exclusive agents in the field episode for your listening pleasure  download our review of 1996s the rock and find out what youre missing  listen now websiteisgiven  therock film seanconnery jamesbond  websiteisgiven',
#  'from the plot of the new james bond movie',
#  '   also',
#  'prins    dang i missed that part',
#  'discussing notimetodie with  continues with episode 5 supporting characters we talk the scooby gang amp',
#  'why cant they just cast henry cavill as the next james bond mans the best fit',
#  '  tom holland for the new james bond ',
#  '    would never let this happen he would cut of ryans arms and legs just to avoid him playing bond',
#  ' wonderful brings back memories of touring james bond',
#  'james bond no time to die is without a doubt the most stunning',
#  'i really ordered the entire jamesbond collection on bluray cause i wanted the notimetodie steelbook',
#  '    is right hard no this belongs to the brits but it would be phenomenal to see a person of colour in the role im looking at you  ',
#  '   yes yes yes ',
#  '   counterpoint   as the bad guy',
#  '    youd never replace rowan as johnny english',
#  ' one problem  james bond doesnt cry',
#  '   no he has to be british',
#  'i have a question  which was the franchise  the name    or     the number  james bond    or    007',
#  '    iron man is dead',
#  '   i image more as agent 86',
#  'ryan reynolds as james bond i wouldnt be able to take him seriously   websiteisgiven',
#  '   i cant see james bond playing dirty dozens before killing a villain wouldnt be british',
#  ' moving forward should be known as the 007 series and have the current james bond train 4 new spies to be the next 007  which ever is the fan fave will be the next 007 makes it more inclusive while also making 007 be a mantle instead of james b',
#  '   right',
#  ' the matrix trilogy',
#  '   i hereby challenge the broccoli dynasty to cast  as the first male bond babe with the pussy galore name already taken',
#  '   james bond and johnny english crossover please',
#  'introducing the first female james bond  ffxiv ff14 gposers eorzeaphotos ffxivscreenshots  websiteisgiven',
#  'james bond and it aint close',
#  '   personally think it should goto ',
#  'my cat is actually watching james bond with us   websiteisgiven',
#  '   james bond is british right ',
#  'tom holland being james bond would actually give me a reason to watch the 007 films',
#  '   how about the plucky canadian csis agent who first annoys and then helps 007 later in the movie bond is in trouble and out of nowhere ryan flies in and rescues 007later they have aviation gin martinis and bond co',
#  '   well he didnt he literally blew the bloody thing to bits im going to totally ignore the craig era and pick up with the follow up to dad',
#  '   7910 098             077     ',
#  'nextjamesbond ryan reynolds announces interest in 007 role  can he beat tom hardy  jamesbond   websiteisgiven',
#  'thoughts on no time to die  fridaymorning jamesbond writingcommunity  websiteisgiven',
#  'danio   7910 098             077    ',
#  '   hes too funny not sure itd work',
#  '   no no no is right  we used to think you were just a pretty face with a gorgeous body but you are so much more id pay more money to listen to your natural sense of self depreciating humor',
#  ' every halle berry moment and invisible car too ',
#  '   actually',
#  '   7910 098             077    i mean',
#  '   yes yes yes',
#  '   dont do that',
#  'if its true that tom holland sed he wants to play james bond if he does it will be good tomholland jamesbond',
#  ' looks beautiful ',
#  '   dont you mean dr no no no',
#  '   thats a clue right there double no seven',
#  'even tho i love both actor two of em wont fit as james bond',
#  '   fine',
#  '   id like it better for it to be a red herring  goes out for his first mission and instantly dies and we get the real 007 who is nyongo',
#  ' my favorite james bond movie also great to know i am in excellent company and',
#  'i dont know what id do with james bond i dont know if it makes total sense to reboot entirely we just did it and i dont know if enough changed since casino royale for it to be worth seeing his whole life cycle again  heres what i might try if i was in charge',
#  'cant keep track',
#  '   yes yes yes',
#  '   mf thats 0069',
#  '     nope',
#  'we see this bear out in the many adaptations of ian flemings james bond no one can say daniel craigs bond is fundamentally carrying over sean connerys character',
#  '   please',
#  ' er really',
#  'its james bond not fucking spy kids',
#  'black james bond vibes',
#  '   mission impossible',
#  ' as much as i love him',
#  '   with he political correctness the last bond movie was',
#  '  hmm interesting ',
#  'adani is james bond type villain for whom the world is not enough greed         sherry       ',
#  '  i like it too i dont mind my bond films being silly i just dont want them boring',
#  ' dudson  well in that case maybe he should of said jc would of been worse the point is it was a hard question but maybe if hed answered some easier ones then no one would notice him deflecting this he wouldnt even give ',
#  'new james bond movie  it was announced to be released in april 2020 but it ultimately released on theatre on 30th sep 2021 almost 15 years of delay on a movie release',
#  'so the circle expands    and now  i propose to solve this with a combat between them  fair enough i guess for james bonds role',
#  ' i bet it is now wrong for a white actor to play the part of the fictional character othello',
#  ' shame about the ending',
#  '    youre pathetic',
#  'movie spy cia fbi homeland james bond',
#  '   how about taking on dame judi denchs role fully committed and playing it as a british woman',
#  '   fuck yeah',
#  '     we want the next leave  of 6 underground    thank u',
#  '    youve a short memory',
#  '   come on ryan it would be hillarious d ',
#  'to clarify',
#  'no time to die has the worst ending of any james bond film  websiteisgiven jamesbond notimetodie 007jamesbond bond',
#  ' the past isnt but he is',
#  'hon    lol thanks',
#  '   am i the only one who saw him die you cant just recast a dead character and act like it didnt happen imo ',
#  '  and moaning that the next james bond will be a bloody lesbian',
#  '   right with ya on that ',
#  'ok why did no time to die have to have the saddest ending ive seen in a long time  jamesbond bittersweet notimetodie danielcraig',
#  '   7910 098             077    ok kiss me',
#  ' jb inspired nfts at our site',
#  '  looks like moss mate ',
#  ' hey the next james bond thats a great idea god says you have to choose you scripts wisely because it could destroy you the way it destroyed dmx because fuked doreen better then all of yiu come on b i didnt know you liked her like i didnt',
#  'new episode  comin in hot   hot stove obiwan kenobi reaction top 5 movies from the 80s   apple  websiteisgiven spotify  websiteisgiven     backtothefuture starwars batman jamesbond  websiteisgiven',
#  '   yes yes yes',
#  '  it was great',
#  ' thats if they want to keep the role of james bond going but since them don kill the character for no time to die',
#  'when you have no time to worry about your boat looking amazing we work closely with spirit yachtsto deliver the highest quality finish',
#  'jamesbond former canadian prime minister jean cretchien is showing some interest in being the next james bond  websiteisgiven',
#  '   i think  can keep jack sparrow alive ',
#  '   hell no',
#  '   yes hes more of an austin powers',
#  '  lol',
#  'i like you',
#  ' i was quite disappointed in this film expected more',
#  '   sure',
#  'why is bill gates suddenly so interested in spouting off about smallpox why is the new james bond movie about smallpox as a bioweapon why did the biden administration just buy 113 million doses of oral smallpox antiviral  one thing you can never say is you were never warned',
#  '  lol',
#  '     right',
#  'the names jam  jam creative',
#  'jedi759 gasayouthat was telling me about the james bond movie ',
#  ' but the future is',
#  '      does really matter i think she be amazing as well as him',
#  'check out what i found funko pop  james bond from the spy who loved me 522  james bond 007  websiteisgiven via uk',
#  ' hey',
#  'holy shit good point raised in the  90 second reviews nttd is absolutely going to be the last time bond is operating on her majestys secret service the next bond film will be on his majestys secret service if its contemporary  jamesbond',
#  'check out what i found funko pop  oddjob from goldfinger 520  james bond 007  websiteisgiven via uk',
#  '  lol',
#  'ive said it before and im saying it again',
#  '  they have asked me to be james bond turned them down',
#  '   your protest is noted',
#  ' cried',
#  'pete davidson will date the next james bond',
#  '   nope',
#  '   youre ridiculous',
#  'easily james bonds ',
#  '   agree with you',
#  'that new james bond on demand tonite  sky amazon ',
#  'okayi think its safe to say that everyone wants to be the next  james bond  this week alone   amp',
#  ' there was no need to have killed this james bond off could have just recast the actor and carried on business as usual',
#  'every word is right here  a very personal tribute to daniel craigs james bond  websiteisgiven',
#  '   true love yaz good ',
#  ' james bond couldnt handle you miss but you would be an excellent choice ',
#  '   i could see ryan reynolds taking the franchise back to the roger moore gadget heavy daysit would be so fun',
#  '   idk a canadian james bond would be a big change lol they already had an american one barry nelson 1954 climax episode 3 of the first season',
#  '   whats the canadian version of mi6 the mounties',
#  '   i hear this in the bondjames bond voice saying nono no',
#  '  is he putting in a last gasp attempt to become the next james bond',
#  ' should be john cena playing a chinese james bond',
#  '   what if we cast another white cishet male sooo radical  websiteisgiven',
#  '   i mean',
#  'tom holland talks about being the next james bond a lot',
#  'omg  i absolutely cannot wait for the red  notice sequel with ryan reynolds the next james bond and the wok  john xinas friend the first one was a cinematic masterpiece  and christopher nolan   should take notes on how to make a real movie ',
#  ' oh nahh 007 will always be for james bond',
#  'if  wants to be the next james bond  well',
#  '   he is a bodyguards wifes husband or something of the sort he has a frickin triple a rating for goodness sakes well',
#  ' james bond cannot have twink energy gender',
#  '   but live his style',
#  '   maybe jimmy bond the lesser know half brother of james bond',
#  ' but james bond is ',
#  '   not sophisticated enough',
#  'its not great enough if compare to original anime but if judging by itself cowboybebop live action on netflix is a very enjoyable space western show feels like james bond films in roger moores era and quentin tarantinos film mixed together  websiteisgiven',
#  '    johnny canadian',
#  '   ryan you would not only bring the suave to it but also add some humor  websiteisgiven',
#  'yesterday we released our third podcast episode on james bond  were talking about the evolution of the  franchise  click below to listen  notimetodie   apple  websiteisgiven  spotify  websiteisgiven  websiteisgiven',
#  ' trash movie',
#  ' consistently my no 1 jamesbond film theworldisnotenough',
#  'consistently my no 1 jamesbond film theworldisnotenough',
#  'new post no time to die now available to stream in uk jamesbond  websiteisgiven',
#  'james bond drawing night at illustrationisolation was a blast keep sharing your awesome sketches with us and catch the next livestream every thursday at 4 pm pt  tyler clark  websiteisgiven',
#  '  since when was james bond a twink',
#  'has anyone else seen the new james bond notimetodie  what did you think',
#  '   should be  to be a real change  websiteisgiven',
#  ' lil disappointed this time bond has been given an emotional touch sort of a family man daniel looked better as suave',
#  '   sorry you been caught  websiteisgiven',
#  'can someone at skystore sky explain the 1599p fee to rent a film in uhd hd and sd without mentioning the words sheer outright greed jamesbond notimetodie',
#  ' mine was tswlm in my humble opinion a near perfect film there have been great ones',
#  ' henry cavill is going to be the next james bondilu but sorry ryan',
#  'james bond has the such a different meaning for me now and i wish wed just retire the series   its played out',
#  ' sean connery   the only bond james bond ',
#  'when you have no time to worry about your boat looking amazing we work closely with spirit yachtsto deliver the highest quality finish',
#  '   no',
#  ' i didnt know that about james bond i made a tweet about the purple pitcher plant yesterday just been hearing more about smallpox since summer specifically june',
#  '     this actually isnt a bad pitch',
#  '  twitter says otherwise  websiteisgiven',
#  '   if this happened id actually consider watching ',
#  '   7910 098            077     awww ly sweat',
#  'they tried to make me play james bond but i said no no no',
#  '   i couldnt take the bond franchise serious anymore every minute i would wait for a crack up line from ',
#  'james bond will return   007notimetodie',
#  '   i like jon hamm but ryan reynolds would have been a great fletch',
#  ' theres very little about dad i dont love  that sword fight is easily one of the best scraps in bond history',
#  '    ryan is a female bond sheesh',
#  '   i agree',
#  'bob odenkirk for james bond pass it on',
#  '    why not',
#  'wb   well then ryan can be her sidekick',
#  '   oh but yes',
#  '   dr no then sure',
#  '    a canadian accent is acceptable',
#  '   he is my pick a soft reboot and there were bond references in the movie  websiteisgiven',
#  '   a canadian bond what a brilliant insight if not a traditional bond ',
#  'die another day has grown on me quite a bit over the last year and a half',
#  '   that would require him to be serious we cant have that',
#  '   7910 098             077    thats so sw',
#  '   what about playing a bond villain though ',
#  ' oh my man  this style is a signature ',
#  'everyone wants to be the next james bond',
#  '   hahaha someone came to play',
#  '   kate beckinsale is not a sidekick my friend',
#  ' pretty much so     the question begs',
#  'this stuff is literally out of a james bond movie like what whereispengshuai',
#  '   you know its going to happen',
#  '   the agent deadpool 007',
#  'id watch that film  saving wrexham from a global threatrain   ryan reynolds wants to be the next james bond   jamesbond    websiteisgiven',
#  '   much rather have deadpool 3 lol',
#  'hard to go wrong anywhere here but the james bond aston martin db5 is on my list of things to buy if i ever win the lottery',
#  ' this line would work if you didnt kill off bondspoiler alertat the end of the movielet me think how to cop out the next james bond moviei knowplastic surgery always works when you have run out of ideas',
#  '   but ive been expecting you',
#  '   how about a canadian version of bond where he says oo like oo in moo and none of the bad guys can kill him because hes too nice',
#  ' the only fair way to do this is to have all the potential names of the actors thrown into the box',
#  '    has too many franchises already all well deserved',
#  '   he looks exactly like the next 007  just saying',
#  '   now thats a hard no the rock should not be bond',
#  '   danny devito for bond',
#  '   i agree bond is too serious more deadpool',
#  ' wb   or ryan as the sidekick to a bad ass bond girl  ryans to cheesy to be a good bond',
#  '30dayjamesbondchallenge day19  if i were jamesbond',
#  '   7910 098            077     i should say thi',
#  ' also',
#  ' i dont know it is with modern directorsscreenwriters jj abrams killed han solo',
#  '   they werent funny reynolds is all funny',
#  '   i dunno',
#  'richardmadden bond girls cast varies based on the plot where it is played continent and actual stories that have been written so far according to current stories',
#  'chance93   rarely funny youve never watched connery or moore have you',
#  'bob  bob',
#  '   whyyyyyyy you are the best choice for the role',
#  '   i think you have the opening for deadpool 3',
#  '   no bond is smooth',
#  '   hed make a great q',
#  '   i dont want a 007 deadpool without a mask love his movies because of the humor he brings',
#  '   anyway ive already chosen our next bond',
#  '   thinking about doing something radical its like a rocking chair',
#  '   yes yes yes',
#  '   yikes bad take',
#  'everyone pretty much has seen a jamesbond film',
#  '  0069 a better fit',
#  '   yes yes yes',
#  'sir you are too massive you could faster play a bond vehicle than james bond himself',
#  '   whilst i adore ryan',
#  '   kind of a bondaustin powers hybrid',
#  '   i think it should be an unknown actor a search needs to begin',
#  '   not going to be the same when he adds the aye to the end of everything',
#  'james bond is more real than the actors who played him  websiteisgiven',
#  '  you ruined your own essence',
#  '   you just nominated yourself mister',
#  ' i mean',
#  '   yes yes yes  ryan youre a pro lets hear you say shaken not stirred in your best british accent',
#  'wb   i do love me some kate maybe a bad ass bond girl sidekick to ryan',
#  '   great actor but wrong for the part',
#  '    im just waiting for his next deadpool movie so there can be a trilogy everyone loves a trilogy',
#  '   why not yougood',
#  '   perhaps the david hedison cia liason character',
#  '   hear me out',
#  ' dude knows he wont be james bond',
#  'quest      bit of an age gap between the two though',
#  '   and a weapon of choicea pez dispenser',
#  '   i just noticed ryan has a fruit gusher shaped forehead',
#  'ryan reynolds says hed be the next james bond if people would let a canadian play the role  full article here    websiteisgiven  narcitycanada canadanews canada  websiteisgiven',
#  'sorry greenlantern  james bond does not blow dudes',
#  ' this is one of the greatest titles sequences that i have seen from the james bond films',
#  '   maybe 00maple syrup as a canadian version of bond wearing a mountie suit',
#  'my first james bond adventure at the cinema was released 22 years ago theworldisnotenough  websiteisgiven',
#  '   7910 098            077     even after',
#  'according to its facebook page the toro restaurant at 1760 scottsville road will open at 4 pm today it is located in the former home of buckhead kitchen amp',
#  ' please stop fooling around its well over a week since i sent queries by email and still waiting for a reply all i get are further requests to resubmit  email address infocouk if no proper response by monday im escalating',
#  ' websiteisgiven  incheon ganghwagun',
#  'the wellknown panda express restaurant was facing a sales slump to fix it',
#  'a mccalls scotland st books  are a copy of my restaurant  review 42nd st it is libelous  as it talks  of my colt misubushi broken into and being crushed in brussels elaine garlic from oldham was in the homeless centre  port namur and on my eurostar train',
#  '  wont be good for the restaurant and wine biz',
#  'minsk group ressurectedand searching for the best restaurant in vienna   websiteisgiven',
#  ' i thought you knew that monday thru thursday',
#  'gregdickinson  booster jabs now required for over 60 here in greece amp',
#  'wolfgang pucks downtown la restaurants wp24 and nest have closed    see there is positive things as a result of the pandemic    websiteisgiven via ',
#  'watch rivals uga and georgia tech play at bobby dodd stadium saturday',
#  'back in august',
#  '11 i do this sometimes lol',
#  'shawn yesterday in a restaurant in new york   websiteisgiven',
#  ' place as in restaurant or a trip to a country',
#  'kirstysnp and just how many of this vast majority who contacted you ie were not blocked by you are reliant on the oil and gas industry for their jobs  i include shops restaurants service industries tradesmen etc in that  you are being economicsl',
#  'swiggycares i had word with him explained him were to deliver then his number was not reachable',
#  'local favorite restaurant  commercial conversion   family style',
#  '  who wants you to be tested to enter right now all you need is a mask',
#  ' ncoelotd wow that was a nice dayshift at our local restaurant huh old sport',
#  'any pasta restaurant recommendation',
#  'shoutout to our coalition members',
#  'realdonaldtrump would like the chicken nuggets meal with a side of fries and a small cocacola  websiteisgiven',
#  ' ill look up that restaurant before next week for sure im kinda looking for specific things to do there than i can only find in vegas i already bought a ticket to jump off the stratosphere next friday but thats all i have planned so far',
#  'left this note at a restaurant in sampaloc exactly 2 yrs ago  uwu manifest it rphs  websiteisgiven',
#  'visit our restaurant of the month  pizza express pheasantry in chelsea live music and fabulous pizzas all in an elegant venue in the basement of a historic building on chelseas kings road great gifts and 20 off pub tokens',
#  'we are hiring senior service manager needed for upscale restaurant in houston',
#  'i need me some general tsos chicken and vegetable lo mein in my life rn but the delivery fee is too high and i dont feel like going to the actual restaurant to get it later  websiteisgiven',
#  'uticaeric greenwald is the kind of guy who can eat at the worlds best restaurant',
#  'nuthin like listening to louis armstrong in new orleans sippin a black coffee sad none of the restaurants were open',
#  'i remember talking to doctors about a year ago who were devastated about the storm facing arizona before the vaccine knowing it would mean thousands of deaths and hospitalizations  yet nothing was being done for mitigation  except heaters for restaurants',
#  'antovolk yougov surveys have always shown the public is in favour of vaccine passports',
#  'a nice cup of tea and carrot cake to finish off a super lunch  cheam  the staff are always so friendly',
#  'lrt this is funny bc ketchup is always cooking in my island so i made her the chef in my resort restaurant too haha',
#  '  you return the bright smile as you walk into the restaurant a waiter comes up',
#  'please take care of yourself and others stay safe from covid19 wear a face covering   in busy places amp',
#  'we can also take you to shops and restaurants whose manager can speak casual english we hope you will find it convenient',
#  'a weird thing about being exfamp',
#  'the wellknown panda express restaurant was facing a sales slump to fix it',
#  'entertainment village with distillery',
#  ' she knows everything about these restaurants',
#  'haechan ended up catching the fish from the restaurant bcs he couldnt catch any in the sea   websiteisgiven',
#  'there was no massive shortage of labourers  only a shortage of employers willing and able to pay and treat workers fairly  opinion there are still reasons to be hopeful about the future of restaurants  if diners and workers unite via   websiteisgiven',
#  'local restaurants will be showing the football game so join fellow alumni and friends to cheer on the ichabods  iron rail brewing 705 s kansas ave johnnys tavern topeka 2821 sw fairlawn rd  the pennet 915 s kansas ave skinnys sports bar amp',
#  'local eateries are struggling to find workers after the pandemic but its not just the fast food industry thats struggling',
#  'fresco restaurant pizza amp',
#  ' my friend asked me to go out today and i said yes and we went to this amazing restaurant beside the unique candle or lamp on every table',
#  'hey britain',
#  'december 2021 issue of southside magazine is out now  its our christmas special markets illuminations wreath making and our gift guide  plus meet the winners of the westside restaurant amp',
#  'the wellknown panda express restaurant was facing a sales slump to fix it',
#  '  of course',
#  ' stories every day yesterday a small restaurant got 350',
#  '  oooh',
#  'coronation chicken terrine',
#  ' try brisko restaurant after union bank for pz',
#  ' p86   mandatory vaccination for everyone',
#  'my restaurant name will be shitty ingredients',
#  ' hi rohit',
#  'congrats to   how lucky is the  to get her deep connections and knowledge of the restaurant scene  websiteisgiven',
#  'enjoy the best of sydney harbour at this worldclass address   websiteisgiven restaurant hotel bar parking traveler sydneylocal australia newsouthwales adele blackfriday crypto dhamaka enhypen fridaymorning internationalmensday lockdown monstax pakvsban  websiteisgiven',
#  'looking forrrrr a restaurant in cebu w function room ',
#  ' golly',
#  'although it is pretty funny that chefs lose their mind over getting their restaurants rated by a tire company ingroup ranking systems rule everything around me',
#  'where exactly does the halfsandwich come from are you giving me half of someone elses sandwich',
#  '   no one said exclude them from your social circles you apparently took his statement personally people in extreme poverty dont expect their friends to attend birthday dinners on restaurants',
#  'we are hiring experienced multiunit director of operations for mexican restaurant  websiteisgiven jobs houston',
#  'new tough rules for bavaria in bavarian corona hotspots with a sevenday incidence of more than 1000 public life is to be shut down in large areas there restaurants sports and cultural facilities have to close and events are prohibited   websiteisgiven  websiteisgiven',
#  'they have all it takes to eat at a top tier restaurant but no oo my boys i love them be humble emmarose',
#  ' websiteisgiven  websiteisgiven entertainment village with distillery',
#  'do you know why there seem to be not enough seats in airport transit lounges  heres why behavioural science  the airport operators do it so that to sit down',
#  '3 a movie theater concession stand',
#  ' hmmmm frida i think its mexican restaurant',
#  'dirtyjesus     ooh boy it means that you are not married yet  trust me its difficult bro live with one then again these many you will be a a dead man in no time  the',
#  'augustbythepond i hope you get her it does seem like the dlc has been including at least one new villager a day for me although',
#  'i couldnt agree more with eric adams that the ban on propane heaters needs to be lifted eating outdoors in the winter is cold and restaurants will suffer',
#  '  speaking of food do you know what time you will be playing alices restaurant on thursday i need to plan my menu prep accordingly as my daughter says when is that crazy song on so we can make stuffing its a tradition',
#  '  shawn at a restaurant in nyc yesterday  websiteisgiven',
#  'dont you just love chinese food   restaurant bans chinese man from allyoucaneat buffet for eating too much   websiteisgiven',
#  'diver the castle and the chain bridge theres also gundel restaurant but it may be closed superb traditional food and gypsy violins',
#  ' what restaurant',
#  'grab the restaurant',
#  ' the challenge is the settings where transmission is most likely',
#  'reminder our 20 allyoucaneat brunch buffet is tomorrow   websiteisgiven we are reminding you that our brunchbuffet is tomorrow',
#  'nov 19 specialsbutter chicken on basmati rice amp',
#  'need to schedule a hair appointment today because apparently im going to a nice restaurant for thanksgiving and my mom will blow up at me if she finds out me hair bad',
#  'they wouldnt let me host diners driveins amp',
#  'nolore retail amp',
#  'help my family just planned to have a family dinner at a restaurant',
#  'javiergoya7  my family has 70 years in the restaurant industry weve been waiting over 7 months for a hvac unit for one location weve been waiting over 6 months for a fryer',
#  ' isback   did you listen to bookworm 2s connection between bot sentinel',
#  'amanda martinez texas karen who threw hot soup at restaurant workers face arrested smartnews   websiteisgiven',
#  ' shawn mendes in a restaurant',
#  'during our visit to najd village heritage restaurant in riyadh',
#  'we are hiring experienced multiunit director of operations for mexican restaurant  websiteisgiven jobs houston',
#  'on my way to berlin at the moment and im so excited about the msian restaurant lmao',
#  'if you were sat in a restaurant with a famous celebrity who would it be mine is definitely adil ray',
#  ' matter18   booh     nonconformity     thank you youre absolutely correct thats why im spending a lot of ',
#  ' i too tried to reach your delivery executive as well as your restaurant but none responded to my call',
#  'them margaritas from the mexican restaurant gone get you there every time  me amp',
#  'find out about restaurant and business openings',
#  'i congratulate and commend the  hotel for excellent  standards despite the tough covid timesi also recommend sizzlers restaurant in diani juicy steaks  websiteisgiven',
#  'india hey india ',
#  'z56cjt  how about travel',
#  ' why wouldyoutake me on a date to my boyfriends restaurant',
#  'lexathecoolkid theres a restaurant near me that does romanian foods',
#  'robicellis also lol i will be in baltimore next week and can explain them but i will need like',
#  'kinda sucks that covid had a profound effect on restaurants and i dont know what its been but the last three sit down spots ive been to ive personally felt like i can do better than this and i cant cook for shit',
#  ' shawn mendes in a restaurant in new york yesterday  websiteisgiven',
#  '  also',
#  'this restaurant i went to one time served us corn bread with literal corn in it and im genuinely traumatized',
#  'chicago  a thinsliced roast beef sandwich garnished with sauted peppers hot or sweet all immersed in the beef cooking juices find out where to get it gt',
#  ' hey francesca',
#  '5 denver restaurants are offering thanksgiving takeout meals  find out which ones',
#  '5 denver restaurants are offering thanksgiving takeout meals  find out which ones',
#  '5 denver restaurants are offering thanksgiving takeout meals  find out which ones',
#  '5 denver restaurants are offering thanksgiving takeout meals  find out which ones',
#  '5 denver restaurants are offering thanksgiving takeout meals  find out which ones',
#  '5 denver restaurants are offering thanksgiving takeout meals  find out which ones',
#  '5 denver restaurants are offering thanksgiving takeout meals  find out which ones',
#  '5 denver restaurants are offering thanksgiving takeout meals  find out which ones',
#  'have you heard anything about what happened outside your restaurant today no what happened',
#  'i finally decided i dont believe in tipping its not my fault that corporations are underpaying and everyone just excepts it bc were in a fked position to take it so am i amp',
#  ' the boy in the striped pajamas never cried more to any other movie',
#  'like a protagonist from a movie',
#  ' and he stripted in the credits of the dbs movie',
#  'did anybody remember this movie  websiteisgiven',
#  'i do wonder why the soundtrack was released before the movie i thought they were usually released afterwards regardless',
#  'could be the setup to a magical realist heist movie or a kojima game plot point youre expected to accept without questioning',
#  'im beyond excited and super proud to be a part of the female gaze  a movie poster project with over 30 talented female artists organised by the brilliant posters  thank you so much eileen ',
#  '  it was a beautiful and heartwarming movie everyone was great and i loved it',
#  ' 1 also',
#  ' honestly both movies arent as bad as people pretend',
#  'population control  yall watch all this old hood movies but dont take shit in',
#  'the only way dc movies making profit is saving the light bills',
#  ' this one is gonna take a while to explain in the movie brother bear there are these two comic relief mooses who in the portuguese dub are voiced by famous in portugal comedy duo toni amp',
#  ' watching the batman trilogy because christopher nolan movies are super interesting and batman is a great character  watching the batman trilogy because cillian murphy is sexy and even though hes in like 7 scenes its worth it because hes sexy',
#  ' my alltime fave movie still the king',
#  'only one week until this becomes a holiday  movie account what are you most excited to watch',
#  'virtue signaling critics on ghostbustersafterlife it was too much fan service is it bad to give the fans what they want  who the hell are these movies for then the non fans who are activists disguised as reviewers cmon dude',
#  '         gal10   kountrygirl      thank you terry  hav',
#  'leo ni friday',
#  'i was a little surprised not seeing adam last night on the red carpet for the gucci movie premiere in la',
#  '   its not just buy and hold we need to invest in our company going to the movies and purchasing food and drinks not to mention buy with crypto just saying',
#  ' i also poised netflix  when they need better movies ',
#  'holy holy holy  man besides a wes anderson movie this is one of the greatest casts of all time insane what  has in it  websiteisgiven',
#  ' can star in my movie ill make when  blows you guys dont miss out youre still early before this ship takes off to the moon  pandagirltoken pandagirl pandagirlmoon',
#  ' love that movie',
#  ' yes',
#  'my sister is watching a hp movie and this one death is so sad',
#  'one pieces creator reveals the first details about the series next movie',
#  'me after watching a brian de palma movie  websiteisgiven',
#  '  some movie by denzel washington ',
#  'i watched love birds on netflix last night',
#  ' suspect boris realised that while they might keep quiet for their old chum',
#  ' rewatch the sopranos or the wire or mad men or the west wing or succession',
#  'wow',
#  'house of gucci has been trending for an entire week or more',
#  'great reason to continue going to the movies over watching a film on tv at home  netflixfilms  websiteisgiven',
#  '  okay',
#  'oh theyre so cute i need them in a movie not nwh together asap  websiteisgiven',
#  'ghostbusters afterlife is the mustsee movie this week we had a blast last night for opening night  you can see the iconic ecto1 2016 in our greatyarmouth carpark again this sunday afternoon from 3pm before the matinee movie  websiteisgiven  websiteisgiven',
#  ' depends on my mood but recently movies  hwasa our pride 4daystillguiltypleasure',
#  ' its like the liveaction re movies this could actually be really fun   but stressful and i dont need that in my life right now xd',
#  ' 13th warrior is one of my alltimes',
#  'house of gucci is another american a movie',
#  'being prabhas fan not easy  waiting for 23 years for one movie no ontime updates no perfect photoshoots no pros  handling patience',
#  'we getting a one piece movie about shanks ',
#  ' mcgone gillettes short short man for an antman movie',
#  'my excitement has peaked',
#  'ending the day on someones couch',
#  'it was a lovely movie and you could see the struggles of the poor but now you are just telling me that the rest of the poor people were lazy which isnt true myth of meritocracy is a thing and this movie clearly has the aim to spread it  websiteisgiven',
#  'i hate how i be watching movies to go to sleep sometimes it take me 35 business days to watch a movie lol that shang chi looked cold',
#  'when they remake a movie or tv show the original should be destroyed dont need two entries taking up space',
#  'our thanks to everyone who joined us for tonights baduypride episode about the colorful filmography of brendan fraser it was a fun little journey and it looks like we have a lot of movies to watch   websiteisgiven',
#  'awesome its pretty depressing movie',
#  ' no bc help the grandma how am i supposed to add the movies to my list or whatever',
#  'i love how in horror movies the person will ask is anyone there as if the killer would say oh yes im in the kitchen want a sandwhich',
#  'i pledge my allegiance to teamgalgadot  ready to battle it out for the rarest artefact rednoticetreasurehuntgood movie',
#  'lol',
#  'the clownery of the year making a whole countdown',
#  'yall i keep seeing scenes from the colin kaepernick movie and they are making me angry white people if you are going to procreate with black people dont secretly hate us too',
#  'done bhai  your movie will be super duper hit ',
#  'manuel paused the movie because i cant stop freaking out over sunday cannot imagine a more perfect interpretation of this number weeping and smiling in equal measures',
#  ' official very true bewithme by dimashqudaibergen is an amazing song having all elements of pop',
#  'time off to enjoy ghostbusters afterlife   ghostbustersafterlife ghostbusters ecto1  xbox20 xboxshare weekend movies  websiteisgiven',
#  ' i think i watched the whole movie in the trailer',
#  'jawn finally solving the problem with movie theater popcorn its not wet enough',
#  'one my favorite bts hk stories is about this movie ringo lam expected cyf to bulk up for the role',
#  '  what the ngamshishis call a popocorn movie',
#  'reading mystery novels and watching horror movies how  however in reality i get really scared easily i have a liking for pretty cute stuff pink i love you im a pink lover i love pink  wehavegaeul ive  ',
#  ' ha i have the same vibe right now i recommend adding a hallmark movie into the mix',
#  'he was one of the best parts of the movie he was a damn dog',
#  'do you guys like reading the book or watching the movie first',
#  ' back at it again  boundless audacity and ignorance i would avoid them least they want to start being bold for at least the weekend until they forget about the movie and racism again',
#  'from the sevenhour satantango to terrence malick films',
#  ' serizawa from crow movie',
#  ' superb movie congratulationsso unique ',
#  'look i think this is a great movie concept with the best batman but what matt reeves batman has to offer is more interesting sorry',
#  ' ovivolp eva green one woman one smile 17 movies  websiteisgiven',
#  ' love when a movie uses humor the same way you waggle a toy in front of a baby every time it starts to sniffle',
#  ' loki was really good but its because its just a lot of character development and talking in rooms its not nearly the movie level production we were promised',
#  'these data show that extremes are now far outside the historical experience extreme heat and extreme rainfall are increasing disproportionally',
#  'and germany had the second most expensive catastrophe in 2021',
#  'by now global observation networks  satellites measure continually all radiation coming in and out 000 scientific studies on climate change come out each year 22',
#  'its out our paper on the cognitive  evolutionary foundations of human communication is with ',
#  'my dogs name is minton today he ate my shuttlecock',
#  'sometimes we choose pain people fast whip themselves  walk on fire but these acts dont only affect the people who do them but also those who watch on todays episode i explore the benefits of ritualized suffering w ',
#  'update available for preorder now',
#  'politics and policy from across the political spectrum with a rotating cast of voices ',
#  'reminder new postdoc position at the university of toronto',
#  'this paper forthcoming in cognitive science began as a proposal for franks devpsych class w thentf ryousif',
#  'my lab is hiring we are looking for a research specialist aka lab managerfulltime ra this is typically a role for a recent college grad and an esp great fit for someone interested in soc or dev psych grad school in the future apply by jan 31',
#  'former new york times journalist chris hedges on the israel lobby campaign to get cornel west out of harvard university',
#  'funfact2 one year later',
#  'funfact when i was only 4 years old',
#  'a strong winter storm in the us is bringing heavy snow to parts of the lower great lakes',
#  'charles mcgee he flew a total of 409 combat missions in world war ii and the korean and vietnam wars',
#  'the philippines is grappling with a record covid surge cases appear milder than during previous outbreaks and hospitals are not yet overwhelmed',
#  'broadway producers have come up with a way to keep shows running amid the surge in virus cases',
#  'the fbi identified a british national as the man who took hostages in a texas synagogue on saturday he was killed during the rescue operation british authorities confirmed counterterrorism police are involved in their investigation',
#  'countries like serbia',
#  'marine le pen has long used fiery rhetoric to fight her way to power in france but she kicked off the final stretch of her third presidential campaign with a video speech',
#  'in south africa you cannot criticise the judiciary',
#  'more than 1 according to a washington post investigation of censuses and other historical records',
#  'three killed in suspected drone attack on uae capital',
#  'fbi investigating texas synagogue attack as terrorism as uk takes two teens into custody',
#  'perspective neighboring families have sons who play together sometimes',
#  'more than a thousand community members filled the blocks outside the islamic cultural center in the bronx on a bitterly cold sunday morning',
#  'last sunday including eight children the youngest victim was 2 years old and the eldest 50',
#  'texas synagogue hostage taker identified as 44yearold british man',
#  'more than 150 million trees are planted in finland every year theyve prohibited forest destruction since 1886 and more than 75 of the countrys surface area is covered',
#  'women get a better nights rest when theyre sleeping next to do dogs as opposed to men according to researchers from canisius college',
#  'experiencing goosebumps when listening to music may be the result of a different brain structure people who get goosebumps from music tend to have more fibers connecting their auditory cortex to the areas responsible for emotional processing',
#  'the phrase i have a bad feeling about this has been said in every star wars movie',
#  'experiencing goosebumps when listening to music may be the result of a different brain structure people who get goosebumps from music tend to have more fibers connecting their auditory cortex to the areas responsible for emotional processing',
#  'music has been proven to effectively lower stress hormone levels',
#  'saturns moon titan has an atmosphere so thick and gravity so low that you can fly through it by flapping any sort of wings attached to your arms',
#  'breaking flooding in santa cruz california as a result of a tsunami caused by the tonga volcano eruption a tsunami warning is in effect for the us west coast',
#  'earth information provides the evidence for the climate challenges we face informing the potential solutions and whether policies are working join me at cop26 or online this afternoon for the uks perspectives on earth information for climate action websiteisgiven',
#  'defra publish our consultation response on geneediting for crops and livestock today a cautious approach which will unlock the scientific potential of ge to improve the healthiness resilience  environmental impact of the food system read it here',
#  'todays ipcc report reconfirms huge challenge of climate change increased evidence for links to extreme events and sea level make need to transform society clear read csas views here',
#  'this is a nice summary of the greenhouse gas removal demonstrators announced today by news five possible natural approaches which may help reach net zero peat enhanced weathering biochar afforestation and bioenergy crops',
#  'nature can be harnessed in many ways to remove co2 from the atmosphere new news funded projects launch today to rigorously test five approaches in the field results will be very relevant for  thinking about how best to reach net zero',
#  'an independent report on g7 leadership has been published by nick stern it makes clear the importance of environmental sustainability and resilience for successful future growth sound advice for g7 leaders before they meet in carbis bay read it here',
#  '2021 was the fifth hottest year on record and the last seven years have been the 7 warmest years recorded',
#  'a new review preprint cowritten with  in which we consider the implications of dualbodyism for a flys sense of selfhood and consider the sublime transformation of metamorphosis as a gateway to the promised land of comparative circuit neuroscience',
#  'silencing machinery to restrict small rna amplification on transcripts selected by argonautes for longterm silencing websiteisgiven rnaspecialissue condensates',
#  'a british computer scientist recently invented a test of computer rendering technology where you have a photo of a real piece of jewelery in controlled lighting conditions and then you render a similar object with a raytracer and ask people to pick which one is real',
#  'only 1 in 5 a level physics students is female  a figure that has remained unchanged in the last 20 yrs',
#  'dart will reach the didymos system in oct 2022 and smash into dimorphos the impact is expected to change the orbital period of dimorphos around didymos by as much as 10 seconds something that can be accurately measured',
#  'this will allow scientists to determine how efficiently the collision imparts momentum to the target rock this information will be crucial in designing missions that could divert a possible future earthimpacting asteroid',
#  'launcherone payloads should now be being ejected from the upper stage',
#  'falcon 9 second stage just made its second burn to circularize the orbit deployment of the satellites starts in a few minutes',
#  'falcon 9 stage 1 has landed at lz1 on the cape and stage 2 has reached the nominal elliptical parking orbit second burn for second stage at 1620 utc',
# ...
#  'mum blasted for calling her gen z daughter selfish for not having children',
#  "a new device may help blind people ‘see' in infrared",
#  'the xbox series x is in stock at argos today',
#  'merrill lynch executive held after racist attack on store workers is caught on video',
#  'man divorces wife during wedding reception after song causes family row',
#  "emma thompson talks about shooting fullfrontal nude scenes ‘at the age that i am'",
#  "billions of dollars were wiped off netflix's value after wall street took fright at the group's stalling subscriber growth",
#  'airlines demand government rules out future covid border closures',
#  'delivery driver drops food off at wrong house then tells customer to fetch it himself',
#  'airlines forced to operate more flights to avoid losing airport slots',
#  'celebrity endorsements only influence 4 of fashionistas survey says',
#  'adele surprises fans with facetime calls after postponing las vegas residency',
#  'netflix could lose 750000 uk subscribers as disney takes control of hit shows',
#  "court of appeal to hear challenge over media ban from prince philip's will court case",
#  'archaeologists have discovered what they believe is the oldestknown coin mint where miniature shovelshaped bronze coins were mass produced some 2600 years ago',
#  'surprising discoveries in fossilized droppings shrew brains and a coffeecoated rainforest are just a few of our favorite breakthroughs this month',
#  'meet the southern ground hornbill the largest of them all',
#  'the archipelago has bet its future on construction of an artificial elevated island that could house a majority of the population of nearly 555000 people',
#  'in the two years since the cdc confirmed the first case of covid19 in the united states the us death toll has passed 860000 more than 2000 have died every day for the past week',
#  'nailing down the fundamentals underlying the himalaya range is vital to understanding the local risk of earthquakes which threaten hundreds of millions of people living in its shadow',
#  'the pandemic brought together 75 musicians to record an album virtually — creating hope during challenging times',
#  'a humpback whale displays its fluke before diving in antarcticas gerlache strait in this image by photographer paul nicklen',
#  'the environmental impact of certain foods has been researched for more than a decade but this study identifies which individual foods have the biggest effect on the air pollution that causes asthma heart attacks and strokes',
#  "a familyrun chocolatier has claimed that ms has copied its perfect match valentine's gift",
#  'patrick mahomes is one game away from his shot at super bowl redemption but only after he was seconds away from defeat in one of the most dramatic games the nfl has seen',
#  'bbc4 is at risk as the corporation scrambles to plug a £15b funding gap after the licence fee was frozen for two years',
#  "it is a pilgrimage that has been nearly a year in the making the queen is to return to sandringham's wood farm for the first time since philips death",
#  'ministers have been warned that they will have to contend with recordbreaking gas and petrol prices in the event of a russian invasion of ukraine',
#  'russia is exploring multiple ways to destabilise ukraine and topple the prowestern government the united states warned yesterday',
#  "silvio berlusconi has pulled out of the running to become italy's next president amid reports of the former prime minister's growing health problems",
#  'two cabinet ministers have called for an inquiry after nusrat ghani said she was told her sacking as a transport minister in early 2020 was because of her faith',
#  "theodore roosevelt statue removed from museum steps as ‘symbol of progress'",
#  'the bbc said the news story is “overwhelmingly in the public interest” but government sources told the daily telegraph that unmasking the spy could put lives at risk',
#  'ireland lifts most covid restrictions today',
#  'coastguard audio call reveals reality of channel migrant rescue missions',
#  'adele thanked fans on twitter your graciousness and love tonight is overwhelming”objective',
#  'the boss of brewdog has been accused of intimidating former employees before a documentary that investigates claims about a “toxic” work culture is broadcast next week',
#  'an investigation by the times has found middle eastern branches of leading british private schools omitted rules designed to stop homophobic bullying',
#  'civil servants have been told that all desks in whitehall must be occupied from next week as ministers order them back to the office',
#  'joe biden is considering deploying several thousand troops along with warships and aircraft to the baltic region and eastern europe',
#  'black bears are being killed in record numbers in california new data shows as wildfires force them towards busy roads in search of food  ',
#  "boris johnson's plan for workers to return to their daily commute is under threat as rail operators run strippeddown train timetables until the end of february",
#  'boris johnson has ordered a cabinet office investigation into nusrat ghanis islamophobia claims',
#  'police officers who guard downing street have been interviewed by sue gray for the “partygate” investigation',
#  'a jury has criticised police and prosecutors after aquitting a private school teacher who had been charged with sexually assaulting a teenage pupil',
#  'former model katie price faces a possible prison sentence after being accused of sending abusive text messages to the partner of her exhusband',
#  'nearly two thirds of the public back the abolition of the bbc licence fee as the vast majority claim it offers poor value for money an exclusive poll has revealed',
#  'deputy prime minister dominic raab said on sunday that it was extremely unlikely britain would send troops to the frontline',
#  'does canada have its own spy agency lol they send him undercover to stop the japanese mafia from selling imitation canadian bacon in a hot fuzz style movie',
#  'yes i dont want you as james bond',
#  'we all love ryan but he is canadian and instead of killing the bad guy he would try to calm her down by being nice',
#  'youd make a great james bond but youd have to swap the gin for a martini',
#  'he looks like an agent or kingsman type of shit in 2nd go james bond go james bond go go go go',
#  'i agree with ryan reynolds i like the tradition of having english actors play bond and a really controversial actor is someone like idris alba its time',
#  'disappointed in the new jamesbond movie its like they killed the franchise',
#  'james bond dies at the end of the film last line in the credits',
#  'saw the latest james bond film at this fantastic cinema last weekend art direction and styling rud',
#  'beautiful photo',
#  'has anyone ever set a timer on their amazon alexa for 6 minutes only to end it after 3 minutes',
#  'worst bond film of all time',
#  'yes everyone loves ryan',
#  'and and and',
#  'hey why dont you do your own new james bond series',
#  'well',
#  'are you crazy the only logical direction is the jinx series unless it wants 2 it also has a pretty good director',
#  'no',
#  'who is this man james bond',
#  'congratulations capt william h wiley amp',
#  'he would admittedly make a good q',
#  'discover the connection between the vegetable broccoli and the james bond website',
#  '7910 098 077 mr 007 is',
#  'the ending was a bad decision that i think the producers will regret i mean brosnan had to end up in bed with halle berry',
#  'and and and',
#  'more bean than bond',
#  'watch james bond tn',
#  'i spent 18 to see no time to die',
#  'oops spoiler alert you need to check out the rest of the infinity saga',
#  'when i was in high school 9 years ago thai fans cite adeles comeback when she used skyfall as the soundtrack of james bonds film adele tornado',
#  'oh come on i bet you have an amazing british accent',
#  'i am open to offers sell my 1953 safins mask',
#  'i really enjoyed notimetodie',
#  'i dont see tom in another spidey movie',
#  'listen to bonus episode now weve unlocked our first patreonexclusive agents in the field episode for your listening pleasure download our review of 1996 the rock and find out what youre missing listen now',
#  'from the plot of the new james bond film',
#  'likewise',
#  'prins dang i missed that part',
#  'discussion of notimetodie with continues with episode 5 minor characters were talking about the scooby gang',
#  'why cant they just cast henry cavill as the next best fitting james bond man',
#  'tom holland for the new james bond',
#  'would never allow that he would cut off ryans arms and legs just to avoid him playing bond',
#  'wonderful brings back memories of a tour with james bond',
#  'james bond no time to die is without a doubt the most breathtaking',
#  'i actually ordered the entire jamesbond collection on bluray because i wanted the notimetodie steelbook',
#  'its right hard no its owned by the british but it would be phenomenal to see a person of color in the role that im looking at you in',
#  'and and and',
#  'counterpoint as villain',
#  'you would never replace rowan as johnny english',
#  'a problem james bond doesnt cry about',
#  'no he must be british',
#  'i have a question which franchise was the name or number james bond or 007',
#  'ironman is dead',
#  'im imagining agent 86 more',
#  'i couldnt take ryan reynolds seriously as james bond',
#  'i cant imagine james bond playing dirty dozens before killing a villain wouldnt be british',
#  'the future should be known as the 007 series and the current james bond train have 4 new spies to be the next 007 whatever the fan favorite is the next 007 will make it more inclusive and 007 a cloak too instead of james b',
#  'right',
#  'die matrixtrilogie',
#  'i hereby call on the broccoli dynasty to cast the first male bond babe with the already taken name pussy galore',
#  'james bond and johnny english crossover please',
#  'introducing the first female james bond ffxiv ff14 gposers eorzeaphotos ffxivscreenshots website',
#  'james bond and its not close',
#  'personally think it should go',
#  'my cat actually watches james bond with our website',
#  'james bond is british correct',
#  'tom holland as james bond would actually give me a reason to watch the 007 movies',
#  'how about the brave canadian csis agent who first annoys 007 and then helps later in the film bond is in trouble and out of nowhere ryan flies in and saves 007 later they have aviation gin martinis and bond co',
#  'well he hasnt he literally blew up the damn thing i will completely ignore the craig era and move on to the sequel to dad',
#  '7910 098 077',
#  'nextjamesbond ryan reynolds announces interest in 007 role can he beat tom hardy jamesbond website launched',
#  'thoughts are given on no time to die friday morning jamesbond writingcommunity website',
#  'denmark 7910 098 077',
#  'hes too funny im not sure if it works',
#  'no no no yes we used to think you were just a pretty face with a gorgeous body but you are so much more i would pay more money to listen to your natural sense of selfdeprecating humor',
#  'every halle berry moment and an invisible car too',
#  'actually',
#  'i mean 7910 098 077',
#  'and and and',
#  'do not do that',
#  'if its true that tom holland wants to play james bond if he does it will be a good tomholland james bond',
#  'looks beautiful',
#  'dont you think dr no no no',
#  'thats a clue right there double no seven',
#  'although i love both actor two doesnt fit as james bond',
#  'fine',
#  'id prefer it when its a diversion that goes on its first mission and dies instantly and we get the real 007 who is nyongo',
#  'my favorite james bond film too good to know im in excellent company',
#  'i dont know what im doing with james bond i dont know if it makes absolute sense to start over from scratch we just did and i dont know if enough has changed since casino royale to make it worth revisiting its entire lifecycle heres what i could try if i were in charge',
#  'cant keep track',
#  'and and and',
#  'mf this is 0069',
#  'no',
#  'we see this in the many adaptations of ian flemings james bond no one can say that daniel craigs bond fundamentally takes sean connerys character',
#  'youre welcome',
#  'is really',
#  'its james bond not bloody spy kids',
#  'black james bond vibes',
#  'impossible mission',
#  'as much as i love him',
#  'politically correct this was the last bond film',
#  'hmm interesting',
#  'adani is a james bondtype villain for whom the world isnt sherry enough for greed',
#  'i like it too i dont mind if my bond films are silly i just dont want them to be boring',
#  'dudson well in that case maybe he should have said jc was worse the point is it was a tough question but if hed answered a few easier ones maybe no one would notice he fended that off he wouldnt even respond to that',
#  'the new james bond film was announced to be released in april 2020 but it was eventually released theatrically on september 30 2021 almost 15 years delay in a film release',
#  'so the circle widens and now i propose to settle this with a fight between them which is fair enough i think for james bonds role',
#  'i bet its wrong now for a white actor to play the role of the fictional character othello',
#  'shame about the end',
#  'youre pathetic',
#  'movie spy cia fbi homeland james bond',
#  'how about taking on the role of dame judi dench fully as a british woman',
#  'damn yes',
#  'we want the next farewell to 6 subway thank u',
#  'you have a short memory',
#  'come on ryan it would be hilarious d',
#  'to clarify',
#  'no time to die has given the worst ending of any james bond movie website jamesbond notimetodie 007jamesbond bond',
#  'the past isnt but he is',
#  'hon lol thanks',
#  'am i the only one who saw him die',
#  'and whine that the next james bond will be a fucking lesbian',
#  'i agree with you',
#  'ok why did no time to die have to have the saddest ending i have seen in a long time jamesbond bittersweet notimetodie danielcraig',
#  '7910 098 077 ok kiss me',
#  'nfts inspired by jb on our website',
#  'looks like moss mate',
#  'hey the next james bond this is a great idea god says you have to choose your scripts wisely cause it might destroy you like it destroyed dmx because doreen shagged better than you all come on i didnt know you liked her like i do',
#  'new episode coming in hot hot stove reaction from obiwan kenobi top 5 movies from the 80s apple website hosting spotify website hosting backtothefuture starwars batman jamesbond website hosting',
#  'and and and',
#  'it was great',
#  'thats if they want to keep the james bond role going but since they dont kill the character for no time to die',
#  'when you dont have time to worry about keeping your boat looking amazing we work closely with spirit yachts to deliver the highest quality finish',
#  'jamesbond former canadian prime minister jean cretchien has expressed interest in being the next james bond website',
#  'i think jack sparrow can keep alive',
#  'under no circumstance',
#  'yeah hes more of an austin powers',
#  'lol',
#  'i like you',
#  'i was pretty disappointed with this film i expected more',
#  'for sure',
#  'why is bill gates suddenly so interested in talking about smallpox why is the new james bond film about smallpox as a bioweapon why did the biden administration just buy 113 million doses of an oral smallpox antiviral one thing you can never say is you were never warned',
#  'lol',
#  'right',
#  'the names jam jam creative',
#  'jedi759 told me about the james bond film',
#  'but the future is',
#  'its really important i think shes just as great as him',
#  'check out what i found about funko pop james bond from the spy who loved me 522 james bond 007 website',
#  'hi',
#  'holy shit good point made in the 90 second reviews nttd will absolutely be the last time bond operates on her majestys secret service the next bond film will be on his majestys secret service when his contemporary jamesbond',
#  'look what i found',
#  'lol',
#  'ive said it before and ill say it again',
#  'they asked me to be james bond they turned it down',
#  'your protest is noted',
#  ...]

# %% [markdown]
# ### Shuffle text

# %%
# import random
# shuff=text
# twtShuffle=[]

# def scramble(sentence):
#    split = sentence.split()  # Split the string into a list of words
#    random.shuffle(split)  # This shuffles the list in-place.
#    return ' '.join(split)  # Turn the list back into a string

# row=0
# col=0
# for i in shuff:
#    row +=1
#    col = row
#    for j in i:
#       if row == col:
#          twtShuffle.append(scramble(i))
#          col +=1

# print(type(twtShuffle))
# print('rows are: ',len(twtShuffle))
# print('columns are: ',len(twtShuffle[0]))
# # print(twtShuffle)
# print(row)
# print(col)

# # textfile = open("shuffleList.txt", "w",encoding="utf-8")
# # for element in twtShuffle:
# #     textfile.write(element + "\n")
# # textfile.close()

# %%
# text= text+twtShuffle
# text

# %% [markdown]
# ### End shuffling

# %%
ouText = outdomain['tweet'].tolist()   #convert series to list
ouText[16:17]                            #show 3 lines
# Out:
# ['  poor lil man loudlycryingface emojihasbeendetected loudlycryingface emojihasbeendetected loudlycryingface emojihasbeendetected  let him get some sleep bro']

# %%
indomain["subjectivity"] = indomain["subjectivity"].astype('category')
target = indomain['subjectivity'].cat.codes
target = pd.concat([target]*2, ignore_index=True) #repeat target values *x times
# type(target)
target
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1683    0
# 1684    0
# 1685    0
# 1686    0
# 1687    0
# Length: 1688, dtype: int8

# %% [markdown]
# ## Activate next snippet only when text shuffling

# %%
# target = pd.concat([target]*2, ignore_index=True) #repeat target values *x times
# # type(target)
# target

# %%
outdomain["subjectivity"] = outdomain["actual"].astype('category')
ouTarget = outdomain['subjectivity'].cat.codes

# %%
token = Tokenizer()
token.fit_on_texts(text)

# %%
vocabSize = len(token.word_index) + 1
vocabSize #2903 - 4276 vocabularies/ with back translated 3288-4794
# Out:
# 4794

# %%
# print(token.word_index) #how vocabs have been indexed

# %%
encodedText = token.texts_to_sequences(text)
print(encodedText[:3])
print('rows are: ',len(encodedText))
print('columns are: ',len(encodedText[0]))
# Out:
# [[212, 1322, 16, 30, 495, 315, 854, 130, 46, 855, 90, 1595, 3, 316, 1, 1596, 1597, 22, 1323, 856, 110, 1598, 5, 2, 253, 1599, 358, 27], [68, 8, 58, 166, 1600, 15, 12, 10], [39, 65, 91, 70, 28, 254, 110, 6, 728, 4, 496, 1, 3686, 42, 51, 564, 3, 1601, 92, 233, 32, 120, 234]]
# rows are:  1688
# columns are:  28

# %% [markdown]
# ### Make training input equal in size

# %%
maxLength = 100 # make all rows equal in size
fixed = pad_sequences(encodedText,maxlen=maxLength,padding='pre') # could be configured as padding= 'post'
print(fixed)
# Out:
# [[   0    0    0 ... 1599  358   27]
#  [   0    0    0 ...   15   12   10]
#  [   0    0    0 ...   32  120  234]
#  ...
#  [   0    0    0 ...   74 4791 3652]
#  [   0    0    0 ...  846   21  119]
#  [   0    0    0 ...    1 1062 1555]]

# %%
fixed.shape
# Out:
# (1688, 100)

# %% [markdown]
# # 'GloVe' Vectors

# %%
GloveVectors = dict()

# %%
# %%time
# file = open('gloveTwitter/glove.twitter.27B.200d.txt', encoding='utf-8')
# file = open('gloveTwitter/glove.840B.300d.txt', encoding='utf-8')
file = open('dictionaries/gloveTwitter/glove.6B.300d.txt', encoding='utf-8')

for line in file:
    values = line.split()
    word = values[0]                    # to skip the first element which is a word 
    vectors = np.asarray(values[1:])    # to start from the numbers that are located after the word
    GloveVectors[word] = vectors
file.close()
# Out:
# CPU times: total: 21.7 s
# Wall time: 21.7 s

# %%
len(GloveVectors.keys())    #number of keys for twitter GloVe 1193514/ for 300giga vector 400000/ glove.840B.300d 2195884
# Out:
# 400000

# %%
# wordVectorMatrix=np.zeros((vocabSize, 200)) # each word at vocab, should have 200 more dimentsion
wordVectorMatrix=np.zeros((vocabSize, 300)) # each word at vocab, should have 300 more dimentsion

currentWord=0
new_Words=0
for word, index in token.word_index.items():
    vector= GloveVectors.get(word)
    if vector is not None:
        currentWord += 1
        wordVectorMatrix[index] = vector
    else:
        new_Words +=1
print('number of words found in GloVe: ',currentWord)   #number of words found in GloVe:  2654-3908  / back translated 3004-4384
print('number of words out of GloVe: ',new_Words)       #number of words out of GloVe:  249-367     / back translated 283-409
# Out:
# number of words found in GloVe:  4384
# number of words out of GloVe:  409

# %% [markdown]
# ### TF2.0 and Keras Model Building

# %%
X_train, X_tset, Y_train, Y_test = train_test_split(fixed, target, random_state=42, test_size= 0.215, shuffle=True,stratify=target)

# %% [markdown]
# # CNN-Model

# %%
# vecSize = 200
vecSize = 300

model = Sequential()
model.add(Embedding(vocabSize, vecSize, input_length = maxLength, weights = [wordVectorMatrix], trainable = False))

model.add(Conv1D(50, 8, activation='relu'))
model.add(MaxPooling1D(5))

# model.add(Dense(32, activation='relu'))

# model.add(Dense(16, activation='relu'))
# model.add(Dropout(0.01))

model.add(GlobalMaxPooling1D())
model.add(Dropout(0.35))

model.add(Dense(1, activation='sigmoid'))
model.add(Dropout(0.55))

model.compile(optimizer=Adam(learning_rate=0.001), loss= 'binary_crossentropy', metrics=['accuracy'])

print(model.summary())
model.fit(X_train, Y_train, epochs=160,batch_size=2, validation_data=(X_tset, Y_test))
# history=model.fit(X_train, Y_train, epochs=128,batch_size=16, validation_data=(X_tset, Y_test))

#time 2m 22.7s
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 300)          1438200
#
#  conv1d (Conv1D)             (None, 93, 50)            120050
#
#  max_pooling1d (MaxPooling1D  (None, 18, 50)           0
#  )
#
#  global_max_pooling1d (Globa  (None, 50)               0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
#  dropout_1 (Dropout)         (None, 1)                 0
#
# =================================================================
# Total params: 1,558,301
# Trainable params: 120,101
# Non-trainable params: 1,438,200
# _________________________________________________________________
# None
# Epoch 1/160
# 663/663 [==============================] - 5s 2ms/step - loss: 4.6477 - accuracy: 0.6483 - val_loss: 0.4567 - val_accuracy: 0.7300
# Epoch 2/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.5989 - accuracy: 0.6642 - val_loss: 0.4306 - val_accuracy: 0.7438
# Epoch 3/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.4220 - accuracy: 0.6860 - val_loss: 0.4071 - val_accuracy: 0.7466
# Epoch 4/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.4321 - accuracy: 0.6815 - val_loss: 1.2767 - val_accuracy: 0.5702
# Epoch 5/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3870 - accuracy: 0.6762 - val_loss: 0.4003 - val_accuracy: 0.7769
# Epoch 6/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.5821 - accuracy: 0.6770 - val_loss: 0.3459 - val_accuracy: 0.8044
# Epoch 7/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1301 - accuracy: 0.7132 - val_loss: 0.3523 - val_accuracy: 0.7906
# Epoch 8/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3415 - accuracy: 0.7057 - val_loss: 0.3080 - val_accuracy: 0.8182
# Epoch 9/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.7103 - accuracy: 0.6845 - val_loss: 0.3044 - val_accuracy: 0.8209
# Epoch 10/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.4272 - accuracy: 0.7019 - val_loss: 0.3129 - val_accuracy: 0.8127
# Epoch 11/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1373 - accuracy: 0.7177 - val_loss: 0.3594 - val_accuracy: 0.8072
# Epoch 12/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.4915 - accuracy: 0.6981 - val_loss: 0.3107 - val_accuracy: 0.8292
# Epoch 13/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.5480 - accuracy: 0.6891 - val_loss: 0.3131 - val_accuracy: 0.8264
# Epoch 14/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1868 - accuracy: 0.7208 - val_loss: 0.3233 - val_accuracy: 0.8375
# Epoch 15/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.0122 - accuracy: 0.7336 - val_loss: 0.3249 - val_accuracy: 0.8154
# Epoch 16/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3379 - accuracy: 0.7117 - val_loss: 0.3193 - val_accuracy: 0.8264
# Epoch 17/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1853 - accuracy: 0.7155 - val_loss: 0.3707 - val_accuracy: 0.8209
# Epoch 18/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1328 - accuracy: 0.7223 - val_loss: 0.3936 - val_accuracy: 0.8099
# Epoch 19/160
# 663/663 [==============================] - 2s 2ms/step - loss: 3.9043 - accuracy: 0.7306 - val_loss: 0.3525 - val_accuracy: 0.8347
# Epoch 20/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2444 - accuracy: 0.7147 - val_loss: 0.3583 - val_accuracy: 0.8320
# Epoch 21/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.5581 - accuracy: 0.6936 - val_loss: 0.3652 - val_accuracy: 0.8347
# Epoch 22/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.4774 - accuracy: 0.7026 - val_loss: 0.3501 - val_accuracy: 0.8457
# Epoch 23/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.4283 - accuracy: 0.7019 - val_loss: 0.4310 - val_accuracy: 0.8017
# Epoch 24/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3252 - accuracy: 0.7087 - val_loss: 0.7305 - val_accuracy: 0.7410
# Epoch 25/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3593 - accuracy: 0.7072 - val_loss: 0.3813 - val_accuracy: 0.8347
# Epoch 26/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2414 - accuracy: 0.7155 - val_loss: 0.3334 - val_accuracy: 0.8485
# Epoch 27/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2529 - accuracy: 0.7170 - val_loss: 0.3242 - val_accuracy: 0.8457
# Epoch 28/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.6656 - accuracy: 0.6868 - val_loss: 0.3510 - val_accuracy: 0.8320
# Epoch 29/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3004 - accuracy: 0.7087 - val_loss: 0.3612 - val_accuracy: 0.8375
# Epoch 30/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3612 - accuracy: 0.7117 - val_loss: 0.3457 - val_accuracy: 0.8347
# Epoch 31/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3320 - accuracy: 0.7109 - val_loss: 0.3413 - val_accuracy: 0.8512
# Epoch 32/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.1832 - accuracy: 0.7200 - val_loss: 0.3613 - val_accuracy: 0.8402
# Epoch 33/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3130 - accuracy: 0.7132 - val_loss: 0.3614 - val_accuracy: 0.8375
# Epoch 34/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.1537 - accuracy: 0.7238 - val_loss: 0.3952 - val_accuracy: 0.8375
# Epoch 35/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3283 - accuracy: 0.7140 - val_loss: 0.4463 - val_accuracy: 0.8209
# Epoch 36/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.2331 - accuracy: 0.7162 - val_loss: 0.3796 - val_accuracy: 0.8375
# Epoch 37/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3318 - accuracy: 0.7155 - val_loss: 0.3630 - val_accuracy: 0.8430
# Epoch 38/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3590 - accuracy: 0.7125 - val_loss: 0.3481 - val_accuracy: 0.8375
# Epoch 39/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3837 - accuracy: 0.7109 - val_loss: 0.3686 - val_accuracy: 0.8540
# Epoch 40/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.4242 - accuracy: 0.7064 - val_loss: 0.3594 - val_accuracy: 0.8512
# Epoch 41/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.1654 - accuracy: 0.7223 - val_loss: 0.3549 - val_accuracy: 0.8567
# Epoch 42/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3594 - accuracy: 0.7079 - val_loss: 0.3685 - val_accuracy: 0.8485
# Epoch 43/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.5011 - accuracy: 0.7026 - val_loss: 0.3769 - val_accuracy: 0.8567
# Epoch 44/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.1807 - accuracy: 0.7208 - val_loss: 0.3670 - val_accuracy: 0.8595
# Epoch 45/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.2892 - accuracy: 0.7147 - val_loss: 0.3261 - val_accuracy: 0.8567
# Epoch 46/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.2166 - accuracy: 0.7185 - val_loss: 0.3525 - val_accuracy: 0.8485
# Epoch 47/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.2534 - accuracy: 0.7162 - val_loss: 0.3869 - val_accuracy: 0.8512
# Epoch 48/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.3237 - accuracy: 0.7170 - val_loss: 0.3586 - val_accuracy: 0.8485
# Epoch 49/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.4859 - accuracy: 0.6996 - val_loss: 0.3366 - val_accuracy: 0.8457
# Epoch 50/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.1772 - accuracy: 0.7238 - val_loss: 0.3277 - val_accuracy: 0.8430
# Epoch 51/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.5582 - accuracy: 0.6981 - val_loss: 0.3350 - val_accuracy: 0.8430
# Epoch 52/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.2237 - accuracy: 0.7208 - val_loss: 0.3372 - val_accuracy: 0.8457
# Epoch 53/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.1019 - accuracy: 0.7298 - val_loss: 0.3437 - val_accuracy: 0.8457
# Epoch 54/160
# 663/663 [==============================] - 2s 3ms/step - loss: 3.8832 - accuracy: 0.7426 - val_loss: 0.3459 - val_accuracy: 0.8457
# Epoch 55/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.0330 - accuracy: 0.7328 - val_loss: 0.3629 - val_accuracy: 0.8430
# Epoch 56/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.4991 - accuracy: 0.7034 - val_loss: 0.5866 - val_accuracy: 0.8017
# Epoch 57/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.4111 - accuracy: 0.7079 - val_loss: 0.3532 - val_accuracy: 0.8512
# Epoch 58/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.4399 - accuracy: 0.7042 - val_loss: 0.3591 - val_accuracy: 0.8540
# Epoch 59/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.0967 - accuracy: 0.7253 - val_loss: 0.3578 - val_accuracy: 0.8485
# Epoch 60/160
# 663/663 [==============================] - 2s 3ms/step - loss: 4.4297 - accuracy: 0.7079 - val_loss: 0.4327 - val_accuracy: 0.8375
# Epoch 61/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.0440 - accuracy: 0.7328 - val_loss: 0.3939 - val_accuracy: 0.8485
# Epoch 62/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1016 - accuracy: 0.7298 - val_loss: 0.3834 - val_accuracy: 0.8430
# Epoch 63/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3703 - accuracy: 0.7109 - val_loss: 0.4198 - val_accuracy: 0.8292
# Epoch 64/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.5521 - accuracy: 0.6966 - val_loss: 0.4142 - val_accuracy: 0.8375
# Epoch 65/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2782 - accuracy: 0.7177 - val_loss: 0.3771 - val_accuracy: 0.8540
# Epoch 66/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1830 - accuracy: 0.7245 - val_loss: 0.3844 - val_accuracy: 0.8540
# Epoch 67/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3843 - accuracy: 0.7102 - val_loss: 0.3918 - val_accuracy: 0.8540
# Epoch 68/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1603 - accuracy: 0.7260 - val_loss: 0.3658 - val_accuracy: 0.8457
# Epoch 69/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.5595 - accuracy: 0.6989 - val_loss: 0.3620 - val_accuracy: 0.8457
# Epoch 70/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3391 - accuracy: 0.7125 - val_loss: 0.3507 - val_accuracy: 0.8540
# Epoch 71/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4916 - accuracy: 0.7011 - val_loss: 0.3390 - val_accuracy: 0.8595
# Epoch 72/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3012 - accuracy: 0.7147 - val_loss: 0.3815 - val_accuracy: 0.8567
# Epoch 73/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1834 - accuracy: 0.7238 - val_loss: 0.4908 - val_accuracy: 0.8292
# Epoch 74/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.0644 - accuracy: 0.7328 - val_loss: 0.4648 - val_accuracy: 0.8320
# Epoch 75/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4623 - accuracy: 0.7057 - val_loss: 0.4295 - val_accuracy: 0.8402
# Epoch 76/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.5450 - accuracy: 0.7011 - val_loss: 0.5307 - val_accuracy: 0.8320
# Epoch 77/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4446 - accuracy: 0.7064 - val_loss: 0.4111 - val_accuracy: 0.8512
# Epoch 78/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4202 - accuracy: 0.7064 - val_loss: 0.4180 - val_accuracy: 0.8512
# Epoch 79/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1843 - accuracy: 0.7208 - val_loss: 0.4472 - val_accuracy: 0.8402
# Epoch 80/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3390 - accuracy: 0.7125 - val_loss: 0.4232 - val_accuracy: 0.8430
# Epoch 81/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.5025 - accuracy: 0.7034 - val_loss: 0.4256 - val_accuracy: 0.8485
# Epoch 82/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3548 - accuracy: 0.7140 - val_loss: 0.4090 - val_accuracy: 0.8375
# Epoch 83/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4059 - accuracy: 0.7094 - val_loss: 0.4374 - val_accuracy: 0.8457
# Epoch 84/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.0600 - accuracy: 0.7313 - val_loss: 0.4174 - val_accuracy: 0.8430
# Epoch 85/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.0871 - accuracy: 0.7275 - val_loss: 0.4214 - val_accuracy: 0.8457
# Epoch 86/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3250 - accuracy: 0.7147 - val_loss: 0.3963 - val_accuracy: 0.8485
# Epoch 87/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3752 - accuracy: 0.7102 - val_loss: 0.4051 - val_accuracy: 0.8485
# Epoch 88/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3200 - accuracy: 0.7147 - val_loss: 0.6914 - val_accuracy: 0.8264
# Epoch 89/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1324 - accuracy: 0.7253 - val_loss: 0.5034 - val_accuracy: 0.8402
# Epoch 90/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3743 - accuracy: 0.7102 - val_loss: 0.4711 - val_accuracy: 0.8430
# Epoch 91/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1647 - accuracy: 0.7245 - val_loss: 0.4685 - val_accuracy: 0.8430
# Epoch 92/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4982 - accuracy: 0.7034 - val_loss: 0.4852 - val_accuracy: 0.8375
# Epoch 93/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.2269 - accuracy: 0.7223 - val_loss: 0.4681 - val_accuracy: 0.8375
# Epoch 94/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.2741 - accuracy: 0.7200 - val_loss: 0.4685 - val_accuracy: 0.8375
# Epoch 95/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.0072 - accuracy: 0.7366 - val_loss: 0.4594 - val_accuracy: 0.8320
# Epoch 96/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1858 - accuracy: 0.7230 - val_loss: 0.4783 - val_accuracy: 0.8512
# Epoch 97/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3956 - accuracy: 0.7140 - val_loss: 0.4743 - val_accuracy: 0.8402
# Epoch 98/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3839 - accuracy: 0.7102 - val_loss: 0.4626 - val_accuracy: 0.8402
# Epoch 99/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1494 - accuracy: 0.7268 - val_loss: 0.5219 - val_accuracy: 0.8347
# Epoch 100/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.0704 - accuracy: 0.7306 - val_loss: 0.5247 - val_accuracy: 0.8430
# Epoch 101/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4667 - accuracy: 0.7049 - val_loss: 0.6105 - val_accuracy: 0.8264
# Epoch 102/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4378 - accuracy: 0.7087 - val_loss: 0.5377 - val_accuracy: 0.8402
# Epoch 103/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1193 - accuracy: 0.7275 - val_loss: 0.5070 - val_accuracy: 0.8430
# Epoch 104/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3816 - accuracy: 0.7109 - val_loss: 0.5094 - val_accuracy: 0.8430
# Epoch 105/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.6557 - accuracy: 0.6906 - val_loss: 0.4768 - val_accuracy: 0.8402
# Epoch 106/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1864 - accuracy: 0.7223 - val_loss: 0.4830 - val_accuracy: 0.8485
# Epoch 107/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3275 - accuracy: 0.7125 - val_loss: 0.4577 - val_accuracy: 0.8457
# Epoch 108/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.2791 - accuracy: 0.7170 - val_loss: 0.4556 - val_accuracy: 0.8402
# Epoch 109/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1192 - accuracy: 0.7253 - val_loss: 0.4767 - val_accuracy: 0.8430
# Epoch 110/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3674 - accuracy: 0.7125 - val_loss: 0.4730 - val_accuracy: 0.8430
# Epoch 111/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.0817 - accuracy: 0.7298 - val_loss: 0.5135 - val_accuracy: 0.8457
# Epoch 112/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4514 - accuracy: 0.7064 - val_loss: 0.4788 - val_accuracy: 0.8512
# Epoch 113/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1309 - accuracy: 0.7253 - val_loss: 0.4566 - val_accuracy: 0.8430
# Epoch 114/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.2574 - accuracy: 0.7170 - val_loss: 0.4761 - val_accuracy: 0.8430
# Epoch 115/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4979 - accuracy: 0.7042 - val_loss: 0.4707 - val_accuracy: 0.8457
# Epoch 116/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.5450 - accuracy: 0.6996 - val_loss: 0.4509 - val_accuracy: 0.8430
# Epoch 117/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.0376 - accuracy: 0.7313 - val_loss: 0.4490 - val_accuracy: 0.8430
# Epoch 118/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1829 - accuracy: 0.7200 - val_loss: 0.4668 - val_accuracy: 0.8430
# Epoch 119/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.2201 - accuracy: 0.7223 - val_loss: 0.5212 - val_accuracy: 0.8320
# Epoch 120/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1436 - accuracy: 0.7238 - val_loss: 0.4629 - val_accuracy: 0.8375
# Epoch 121/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1904 - accuracy: 0.7215 - val_loss: 0.4579 - val_accuracy: 0.8430
# Epoch 122/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1196 - accuracy: 0.7260 - val_loss: 0.4877 - val_accuracy: 0.8347
# Epoch 123/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1967 - accuracy: 0.7230 - val_loss: 0.5183 - val_accuracy: 0.8320
# Epoch 124/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4000 - accuracy: 0.7087 - val_loss: 0.4147 - val_accuracy: 0.8457
# Epoch 125/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.0907 - accuracy: 0.7298 - val_loss: 0.3919 - val_accuracy: 0.8485
# Epoch 126/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3070 - accuracy: 0.7132 - val_loss: 0.4010 - val_accuracy: 0.8457
# Epoch 127/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1885 - accuracy: 0.7223 - val_loss: 0.4148 - val_accuracy: 0.8485
# Epoch 128/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1143 - accuracy: 0.7283 - val_loss: 0.4234 - val_accuracy: 0.8540
# Epoch 129/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1006 - accuracy: 0.7306 - val_loss: 0.4583 - val_accuracy: 0.8512
# Epoch 130/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.4665 - accuracy: 0.7034 - val_loss: 0.6906 - val_accuracy: 0.8264
# Epoch 131/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3904 - accuracy: 0.7117 - val_loss: 0.4434 - val_accuracy: 0.8485
# Epoch 132/160
# 663/663 [==============================] - 1s 2ms/step - loss: 3.9516 - accuracy: 0.7396 - val_loss: 0.4474 - val_accuracy: 0.8402
# Epoch 133/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.1669 - accuracy: 0.7245 - val_loss: 0.4789 - val_accuracy: 0.8512
# Epoch 134/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3219 - accuracy: 0.7155 - val_loss: 0.4712 - val_accuracy: 0.8512
# Epoch 135/160
# 663/663 [==============================] - 1s 2ms/step - loss: 4.3924 - accuracy: 0.7109 - val_loss: 0.4461 - val_accuracy: 0.8457
# Epoch 136/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.4994 - accuracy: 0.7034 - val_loss: 0.4908 - val_accuracy: 0.8567
# Epoch 137/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.0917 - accuracy: 0.7298 - val_loss: 0.4931 - val_accuracy: 0.8567
# Epoch 138/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3357 - accuracy: 0.7140 - val_loss: 0.5315 - val_accuracy: 0.8457
# Epoch 139/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2866 - accuracy: 0.7177 - val_loss: 0.5934 - val_accuracy: 0.8320
# Epoch 140/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1071 - accuracy: 0.7268 - val_loss: 0.5481 - val_accuracy: 0.8320
# Epoch 141/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1673 - accuracy: 0.7208 - val_loss: 0.4977 - val_accuracy: 0.8430
# Epoch 142/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2265 - accuracy: 0.7230 - val_loss: 0.6266 - val_accuracy: 0.8209
# Epoch 143/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2303 - accuracy: 0.7215 - val_loss: 0.4834 - val_accuracy: 0.8457
# Epoch 144/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1740 - accuracy: 0.7238 - val_loss: 0.4482 - val_accuracy: 0.8457
# Epoch 145/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.0290 - accuracy: 0.7351 - val_loss: 0.5532 - val_accuracy: 0.8375
# Epoch 146/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2470 - accuracy: 0.7177 - val_loss: 0.4780 - val_accuracy: 0.8375
# Epoch 147/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.4230 - accuracy: 0.7109 - val_loss: 0.4514 - val_accuracy: 0.8512
# Epoch 148/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2815 - accuracy: 0.7170 - val_loss: 0.4292 - val_accuracy: 0.8485
# Epoch 149/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3425 - accuracy: 0.7132 - val_loss: 0.4280 - val_accuracy: 0.8457
# Epoch 150/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1698 - accuracy: 0.7253 - val_loss: 0.5065 - val_accuracy: 0.8430
# Epoch 151/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.5359 - accuracy: 0.6996 - val_loss: 0.4924 - val_accuracy: 0.8457
# Epoch 152/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3807 - accuracy: 0.7109 - val_loss: 0.5654 - val_accuracy: 0.8347
# Epoch 153/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.4829 - accuracy: 0.7057 - val_loss: 0.5102 - val_accuracy: 0.8375
# Epoch 154/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.0761 - accuracy: 0.7321 - val_loss: 0.5189 - val_accuracy: 0.8402
# Epoch 155/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3995 - accuracy: 0.7057 - val_loss: 0.5203 - val_accuracy: 0.8485
# Epoch 156/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1622 - accuracy: 0.7260 - val_loss: 0.5623 - val_accuracy: 0.8375
# Epoch 157/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.3452 - accuracy: 0.7140 - val_loss: 0.5188 - val_accuracy: 0.8430
# Epoch 158/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1105 - accuracy: 0.7298 - val_loss: 0.5113 - val_accuracy: 0.8430
# Epoch 159/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.2118 - accuracy: 0.7200 - val_loss: 0.5108 - val_accuracy: 0.8457
# Epoch 160/160
# 663/663 [==============================] - 2s 2ms/step - loss: 4.1096 - accuracy: 0.7306 - val_loss: 0.5565 - val_accuracy: 0.8347

# %% [markdown]
# # LSTM-Model

# %%
# %%time
# vecSize = 300
# Y_train=pd.get_dummies(Y_train)
# Y_test=pd.get_dummies(Y_test)
# target=pd.get_dummies(target)
# ouTarget=pd.get_dummies(ouTarget)
# n_categories=2

# model = Sequential()

# # Keras Embedding layer with Word2Vec weights initialization
# model.add(Embedding(input_dim=vocabSize,
#                     output_dim=vecSize,
#                     weights=[wordVectorMatrix],
#                     input_length=maxLength,
#                     mask_zero=True,
#                     trainable=False))
# # print(w2v_weights.shape)
# model.add(LSTM(20, dropout=0.4, activation='tanh', recurrent_dropout=0.4))
# # # model.add(Flatten())
# model.add(Dense(n_categories,activation='sigmoid'))
# model.add(Dropout(0.55))

# model.add(Activation('softmax'))
# model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy']) #sparse_categorical_crossentropy
# print(model.summary())

# # model.fit(X_train, Y_train, epochs=5, batch_size=16, validation_data=(X_tset, Y_test), verbose=1) 
# model.fit(X_train, Y_train, epochs=64, batch_size=16, validation_data=(X_tset, Y_test), verbose=1) 
# # print(w2v_weights)

# #time: 10min 50.1s

# %%
# history = model.fit(X_train, Y_train, epochs=128,batch_size=16, validation_data=(X_tset, Y_test))

# %% [markdown]
# ## Plotting Loss and Accuracy Graphs

# %%
# import matplotlib.pyplot as plt
# plt.figure(figsize=(12, 12))
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Loss')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()

# plt.figure(figsize=(12, 12))
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('Accuracy')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()

# %% [markdown]
# # in-domain evaluation

# %%
from sklearn.metrics import classification_report
testPredict= (model.predict(fixed) > 0.5).astype("int32")
# testPredict

# %%
print ('in-domain \n',classification_report(testPredict, target))
# Out:
# in-domain
#                precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90       975
#            1       0.82      0.94      0.87       713
#
#     accuracy                           0.89      1688
#    macro avg       0.88      0.89      0.88      1688
# weighted avg       0.89      0.89      0.89      1688

# %% [markdown]
# # Save model

# %%
# save
# model.save("cnnGlove1")

# %%
from keras.models import load_model
cnnGlove=load_model('cnnGlove')

# %% [markdown]
# # Predict out-domain

# %%
encodedOuText = token.texts_to_sequences(ouText)
# print(encodedOuText[17:19])
# print(encodedOuText)
# print(ouText)

# %%
maxLength = 100 # make all rows equal in size
outFixed = pad_sequences(encodedOuText,maxlen=maxLength,padding='pre') # could be configured as padding= 'post'
print(outFixed)
# Out:
# [[   0    0    0 ...   22 1500  130]
#  [   0    0    0 ... 4632  335   37]
#  [   0    0    0 ...   41   69   36]
#  ...
#  [   0    0    0 ...  823    5 2483]
#  [   0    0    0 ...  205 2048   37]
#  [   0    0    0 ...    8  239    6]]

# %%
outFixed.shape
# Out:
# (670, 100)

# %%
testPredict= (model.predict(outFixed) > 0.5).astype("int32")
print ('out-domain \n',classification_report(testPredict, ouTarget))
# Out:
# out-domain
#                precision    recall  f1-score   support
#
#            0       0.62      0.52      0.57       240
#            1       0.75      0.82      0.79       430
#
#     accuracy                           0.71       670
#    macro avg       0.69      0.67      0.68       670
# weighted avg       0.71      0.71      0.71       670

# %%
testPredict= (cnnGlove.predict(outFixed) > 0.5).astype("int32")
print ('out-domain \n',classification_report(testPredict, ouTarget))
# Out:
# out-domain
#                precision    recall  f1-score   support
#
#            0       0.63      0.57      0.60       226
#            1       0.79      0.83      0.81       444
#
#     accuracy                           0.74       670
#    macro avg       0.71      0.70      0.70       670
# weighted avg       0.74      0.74      0.74       670

# %% [markdown]
# # Clustering

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import plotly.express as px
#Libraries for clustering
from sklearn.cluster import KMeans

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
vectorizerTf = TfidfVectorizer(stop_words='english')
vectorizerNtf = TfidfVectorizer(stop_words='english',analyzer='word',ngram_range=(1,2))  
                                                                    #TF-IDF (n-gram level)// 
                                                                    #consider n-grams between 1 (individual words) 
                                                                    # and 2 (sequences of 2 words or bi-grams)
vectorizerBag = CountVectorizer(stop_words='english')

# %%
def cleanWebsite(tweet):
    tweet= re.sub(r'websiteisgiven','',tweet) #remove websiteisgiven ;r-> the expression is a raw string,+ -> one char or more
    return tweet

# %%
indomain['tweetClus']=indomain['tweet'].apply(lambda txt:cleanWebsite(txt))
textCluster=indomain['tweetClus'].tolist()

# %%
xTf=vectorizerTf.fit_transform(inText)
xBag=vectorizerBag.fit_transform(inText)
xNtf = vectorizerNtf.fit_transform(inText)
xTf
# Out:
# <844x3994 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7539 stored elements in Compressed Sparse Row format>

# %%
#Test increments of 100 clusters using elbow method
distortions = []
sse={}
K=range(1,10)
# for k in np.arange(100,900,100):
for k in K:
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(xTf)
    distortions.append(kmeans.inertia_)
    # sse[k] = kmeans.inertia_
# plt.plot(list(sse.keys()),list(sse.values()))
plt.plot(K,distortions,'bx-')
plt.xlabel('Values for K')
plt.ylabel('SSE')
plt.title('The Elbow Method showing the optimal k')
plt.show()

#time 1m 35.7s

# %%
#Test increments of 100 clusters using elbow method
distortions = []
sse={}
K=range(1,10)
# for k in np.arange(100,900,100):
for k in K:
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(xBag)
    distortions.append(kmeans.inertia_)
    # sse[k] = kmeans.inertia_
# plt.plot(list(sse.keys()),list(sse.values()))
plt.plot(K,distortions,'bx-')
plt.xlabel('Values for K')
plt.ylabel('SSE')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
#Test increments of 100 clusters using elbow method
distortions = []
sse={}
K=range(1,10)
# for k in np.arange(100,900,100):
for k in K:
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(xNtf)
    distortions.append(kmeans.inertia_)
    # sse[k] = kmeans.inertia_
# plt.plot(list(sse.keys()),list(sse.values()))
plt.plot(K,distortions,'bx-')
plt.xlabel('Values for K')
plt.ylabel('SSE')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# ### Create clusters

# %%
k=8
kModel=KMeans(n_clusters=k,init='k-means++', max_iter=10000, n_init=1)
kModel.fit(xTf)
# Out:
# KMeans(max_iter=10000, n_init=1)

# %%
indomain['Cluster']=kModel.labels_

indomain.head()
# Out:
#                                                tweet subjectivity  \
# 0     does canada have its own spy agency lol the...   subjective
# 1                   yes i dont want ya as james bond   subjective
# 2     we all love ryan but hes canadian and inste...   subjective
# 3     you woud make a great james bond but you wo...   subjective
# 4  he looks like an agent or kingsman type of shi...   subjective
#
#                                            tweetClus  Cluster
# 0     does canada have its own spy agency lol the...        5
# 1                   yes i dont want ya as james bond        1
# 2     we all love ryan but hes canadian and inste...        7
# 3     you woud make a great james bond but you wo...        1
# 4  he looks like an agent or kingsman type of shi...        1

# %% [markdown]
# ### Output results to a text file

# %%
# clusters= indomain.groupby('Cluster')

# for cluster in clusters.groups:
#     f=open('Cluster'+ str(cluster)+'.csv','w') #create csv file
#     data=clusters.get_group(cluster)[['tweet','subjectivity']] #get tweet & subjectivity columns
#     f.write(data.to_csv(index_label='id')) #set index to id
#     f.close()

# %% [markdown]
# ## Understand what each cluster refers to

# %%
print('Cluster centroids: \n')
orderCentroids= kModel.cluster_centers_.argsort()[:,::-1]
terms=vectorizerTf.get_feature_names_out()

for i in range(k):
    print('Cluster %d:' %i)
    for j in orderCentroids[i, :10]: # print out 10 feature terms of each cluster
        print (' %s' %terms[j])
    print('-----------')
# Out:
# Cluster centroids:
#
# Cluster 0:
#  restaurants
#  ones
#  denver
#  takeout
#  offering
#  meals
#  thanksgiving
#  covid
#  future
#  friday
# -----------
# Cluster 1:
#  bond
#  james
#  websiteisgiven
#  wants
#  007
#  movie
#  ryan
#  holland
#  tom
#  new
# -----------
# Cluster 2:
#  think
#  good
#  business
#  world
#  big
#  actor
#  state
#  restaurant
#  trailer
#  pay
# -----------
# Cluster 3:
#  great
#  live
#  restaurant
#  music
#  sales
#  express
#  panda
#  fix
#  slump
#  wellknown
# -----------
# Cluster 4:
#  restaurant
#  websiteisgiven
#  like
#  dont
#  movies
#  need
#  going
#  life
#  says
#  chicken
# -----------
# Cluster 5:
#  movie
#  just
#  im
#  trilogy
#  watching
#  websiteisgiven
#  love
#  like
#  trash
#  theater
# -----------
# Cluster 6:
#  new
#  york
#  study
#  websiteisgiven
#  university
#  shawn
#  yesterday
#  killed
#  jamesbond
#  like
# -----------
# Cluster 7:
#  yes
#  lol
#  098
#  7910
#  077
#  right
#  mean
#  agree
#  research
#  hey
# -----------

# %% [markdown]
# ### Evaluating Clustering method

# %%
from sklearn.metrics import silhouette_score
silhouette_score(xTf, labels=kModel.predict(xTf))
# Out:
# 0.007133252069057795

# %%
from sklearn.cluster import DBSCAN

dbClus = DBSCAN(eps=1, min_samples=2).fit(xTf)

# %%
indomain['DbCluster']=dbClus.labels_

indomain.head()
# Out:
#                                                tweet subjectivity  \
# 0     does canada have its own spy agency lol the...   subjective
# 1                   yes i dont want ya as james bond   subjective
# 2     we all love ryan but hes canadian and inste...   subjective
# 3     you woud make a great james bond but you wo...   subjective
# 4  he looks like an agent or kingsman type of shi...   subjective
#
#                                            tweetClus  Cluster  DbCluster
# 0     does canada have its own spy agency lol the...        5          0
# 1                   yes i dont want ya as james bond        1         -1
# 2     we all love ryan but hes canadian and inste...        7          0
# 3     you woud make a great james bond but you wo...        1          0
# 4  he looks like an agent or kingsman type of shi...        1          0

# %%
clustUniq=np.unique(dbClus.labels_)
clustUniq
# Out:
# array([-1,  0,  1,  2,  3], dtype=int64)

# %%
print('Cluster centroids: \n')
# orderDbCentroids= dbClus.cluster_centers_.argsort()[:,::-1]
terms=vectorizerTf.get_feature_names_out()

for i in clustUniq:
    print('Cluster %d:' %i)
    for j in range(10): # print out 10 feature terms of each cluster
        print (' %s' %terms[j])
    print('-----------')
# Out:
# Cluster centroids:
#
# Cluster -1:
#  000
#  0069
#  007
#  007jamesbond
#  007later
#  007notimetodie
#  00maple
#  0500
#  077
#  098
# -----------
# Cluster 0:
#  000
#  0069
#  007
#  007jamesbond
#  007later
#  007notimetodie
#  00maple
#  0500
#  077
#  098
# -----------
# Cluster 1:
#  000
#  0069
#  007
#  007jamesbond
#  007later
#  007notimetodie
#  00maple
#  0500
#  077
#  098
# -----------
# Cluster 2:
#  000
#  0069
#  007
#  007jamesbond
#  007later
#  007notimetodie
#  00maple
#  0500
#  077
#  098
# -----------
# Cluster 3:
#  000
#  0069
#  007
#  007jamesbond
#  007later
#  007notimetodie
#  00maple
#  0500
#  077
#  098
# -----------

# %%
from sklearn.metrics import silhouette_score
silhouette_score(xTf, labels=dbClus.fit_predict(xTf))
# Out:
# 0.014350785806533149
